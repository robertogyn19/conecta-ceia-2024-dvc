# %% [markdown]
# ## DVC Versioning Data and Models
#
# - link: https://dvc.org/doc/use-cases/versioning-data-and-models/tutorial
#
# O objetivo desse exemplo é ter uma experiência prática com o básico de controle de versionamento de múltiplos datasets e modelos de Machine Learning usando o DVC.

# %% [markdown]
# ```shell
# # Preparação do código
# git clone https://github.com/robertogyn19/conecta-ceia-2024-dvc.git
# cd conecta-ceia-2024-dvc
# ```

# %% [markdown]
# ```shell
# # Preparação do ambiente
# python3 -m venv .env
# source .env/bin/activate
#
# # Instalação das dependências
# pip install -r requirements.txt
# ```

# %% [markdown]
# ### Inicialização do DVC
#
# ```shell
# # Inicialização
# $ dvc init
# Initialized DVC repository.
#
# You can now commit the changes to git.
#
# +---------------------------------------------------------------------+
# |                                                                     |
# |        DVC has enabled anonymous aggregate usage analytics.         |
# |     Read the analytics documentation (and how to opt-out) here:     |
# |             <https://dvc.org/doc/user-guide/analytics>              |
# |                                                                     |
# +---------------------------------------------------------------------+
#
# What's next?
# ------------
# - Check out the documentation: <https://dvc.org/doc>
# - Get help and share ideas: <https://dvc.org/chat>
# - Star us on GitHub: <https://github.com/iterative/dvc>
# ```
#
#
# ```shell
# # Obtenção dos dados
# dvc get https://github.com/iterative/dataset-registry tutorials/versioning/data.zip
# unzip -q data.zip
# rm -f data.zip
# tree data
# data
# ├── train
# │   ├── cats
# │   │   ├── cat.1.jpg
# │   │   ├── cat.10.jpg
# │   │   ├── ...
# │   │   ├── ...
# │   │   ├── ...
# │   │   ├── cat.102.jpg
# │   │   └── cat.99.jpg
# │   └── dogs
# │       ├── dog.1.jpg
# │       ├── dog.10.jpg
# │       ├── ...
# │       ├── ...
# │       ├── ...
# │       ├── dog.102.jpg
# │       └── dog.99.jpg
# └── validation
#     ├── cats
#     │   ├── cat.1001.jpg
#     │   ├── cat.1002.jpg
#     │   ├── ...
#     │   ├── ...
#     │   ├── ...
#     │   ├── cat.1005.jpg
#     │   └── cat.1400.jpg
#     └── dogs
#         ├── dog.1001.jpg
#         ├── dog.1002.jpg
#         ├── ...
#         ├── ...
#         ├── ...
#         ├── dog.1005.jpg
#         └── dog.1400.jpg
#
# 7 directories, 1800 files
#
# ```

# %% [markdown]
# ```shell
# # Adição dos dados no DVC
# $ dvc add data
# 100% Adding...|██████████████████████████████████████████████████████████████████|1/1 [00:00,  1.18file/s]
#
# To track the changes with git, run:
#
#         git add .gitignore data.dvc
#
# To enable auto staging, run:
#
#         dvc config core.autostage true
# ```

# %% [markdown]
# ```shell
# $ cat data.dvc
# outs:
# - md5: b8f4d5a78e55e88906d5f4aeaf43802e.dir
#   size: 41149064
#   nfiles: 1800
#   hash: md5
#   path: data
# ```

# %%
# Vamos inspecionar esse arquivo .dir do DVC
filepath = ".dvc/cache/files/md5/b8/f4d5a78e55e88906d5f4aeaf43802e.dir"
file = open(filepath, "r")

import json
dvc_data = json.loads(file.read())

# %%
print(json.dumps(dvc_data, indent=2))
# Out:
# [
#   {
#     "md5": "ed779276108738fdb2179ccabf9680d9",
#     "relpath": "train/cats/cat.1.jpg"
#   },
#   {
#     "md5": "10d2a131081a3095726c5721ed31c21f",
#     "relpath": "train/cats/cat.10.jpg"
#   },
#   {
#     "md5": "0f2bfe74e9c363064087d0cd8a322106",
#     "relpath": "train/cats/cat.100.jpg"
#   },
#   {
#     "md5": "cdf4adb5d77200057c3dee2a62a0ee47",
#     "relpath": "train/cats/cat.101.jpg"
#   },
#   {
#     "md5": "7064a0c872b8feb1507ba841e8822c73",
#     "relpath": "train/cats/cat.102.jpg"
#   },
#   {
#     "md5": "412d9692e3067f75c9a984c5681883fe",
#     "relpath": "train/cats/cat.103.jpg"
#   },
#   {
#     "md5": "ebee1b7e74d6e5c70ea65f592ddc935f",
#     "relpath": "train/cats/cat.104.jpg"
#   },
#   {
#     "md5": "06e044feade703648bab0d2f7bfc147d",
#     "relpath": "train/cats/cat.105.jpg"
#   },
#   {
#     "md5": "69d3a61d7d9db45cc96e6e7b2c49bb46",
#     "relpath": "train/cats/cat.106.jpg"
#   },
#   {
#     "md5": "ba86efd9e49ce1e7268593fb32773370",
#     "relpath": "train/cats/cat.107.jpg"
#   },
#   {
#     "md5": "3bd0123fb30b49fd0ba0622e66ff6a21",
#     "relpath": "train/cats/cat.108.jpg"
#   },
#   {
#     "md5": "275aa7d6b4b252a901c6fa322ac8093c",
#     "relpath": "train/cats/cat.109.jpg"
#   },
#   {
#     "md5": "615254850ba0911122b8546b18fd690d",
#     "relpath": "train/cats/cat.11.jpg"
#   },
#   {
#     "md5": "e1db818ef16ab24b2ab4bb711d7a78dd",
#     "relpath": "train/cats/cat.110.jpg"
#   },
#   {
#     "md5": "eb0039de3374f57e0410e3f8a3da612a",
#     "relpath": "train/cats/cat.111.jpg"
#   },
#   {
#     "md5": "2040ed036fec261d193697c2568db659",
#     "relpath": "train/cats/cat.112.jpg"
#   },
#   {
#     "md5": "857adac16fcc77240821e3cdaf0d5e21",
#     "relpath": "train/cats/cat.113.jpg"
#   },
#   {
#     "md5": "7ef30a20d20cbed84ed5b1c839058215",
#     "relpath": "train/cats/cat.114.jpg"
#   },
#   {
#     "md5": "60b678c72af4e0e51762c66204cfbaab",
#     "relpath": "train/cats/cat.115.jpg"
#   },
#   {
#     "md5": "788d5970a5d30c51b78ca812277a47a6",
#     "relpath": "train/cats/cat.116.jpg"
#   },
#   {
#     "md5": "0a2c9f0f61eeabcaf2331da4710f994d",
#     "relpath": "train/cats/cat.117.jpg"
#   },
#   {
#     "md5": "f240d842de9855b13c9050915671efbf",
#     "relpath": "train/cats/cat.118.jpg"
#   },
#   {
#     "md5": "508cfe5bdc7c65d6d6b10611c747f790",
#     "relpath": "train/cats/cat.119.jpg"
#   },
#   {
#     "md5": "551a18be81e3ea620b9541a0d258c79b",
#     "relpath": "train/cats/cat.12.jpg"
#   },
#   {
#     "md5": "f899eb299ba1769fa6e2a698de31df31",
#     "relpath": "train/cats/cat.120.jpg"
#   },
#   {
#     "md5": "2260ee2db1ea4b0e27be2be94a453c4a",
#     "relpath": "train/cats/cat.121.jpg"
#   },
#   {
#     "md5": "df37c38e766f657c2f681e17b0d56c57",
#     "relpath": "train/cats/cat.122.jpg"
#   },
#   {
#     "md5": "d0a99d16123f02832c26cb8deec46c43",
#     "relpath": "train/cats/cat.123.jpg"
#   },
#   {
#     "md5": "24fda6ddca9ee2c1b85a463141f4d7a6",
#     "relpath": "train/cats/cat.124.jpg"
#   },
#   {
#     "md5": "ecb6502284977f431aa6378ad5438a2a",
#     "relpath": "train/cats/cat.125.jpg"
#   },
#   {
#     "md5": "60bcb1b1947fe2baff0f06be28e84eba",
#     "relpath": "train/cats/cat.126.jpg"
#   },
#   {
#     "md5": "a44118d1699c578415ea5b84a499cff6",
#     "relpath": "train/cats/cat.127.jpg"
#   },
#   {
#     "md5": "1240b6ef292309d53c7c943308368b63",
#     "relpath": "train/cats/cat.128.jpg"
#   },
#   {
#     "md5": "f2f6171ed2cb31ff8fe206b212e5ccc7",
#     "relpath": "train/cats/cat.129.jpg"
#   },
#   {
#     "md5": "456f6f80a6699a03295a32984210578b",
#     "relpath": "train/cats/cat.13.jpg"
#   },
#   {
#     "md5": "fe7684d4f5ac9dc804e1c7d32ba55218",
#     "relpath": "train/cats/cat.130.jpg"
#   },
#   {
#     "md5": "a94fa44eac0872a77fc05714668965d5",
#     "relpath": "train/cats/cat.131.jpg"
#   },
#   {
#     "md5": "9664b23fedfdeaaa63c916deb96efc39",
#     "relpath": "train/cats/cat.132.jpg"
#   },
#   {
#     "md5": "66dae9343d6be874c95eabee2122dbff",
#     "relpath": "train/cats/cat.133.jpg"
#   },
#   {
#     "md5": "7ccafae17297feccfca25d4be370169d",
#     "relpath": "train/cats/cat.134.jpg"
#   },
#   {
#     "md5": "caa36b51931687e1f4f858f48cfc1ea8",
#     "relpath": "train/cats/cat.135.jpg"
#   },
#   {
#     "md5": "861ac10ef2683f99d460dfd9ea2de8b9",
#     "relpath": "train/cats/cat.136.jpg"
#   },
#   {
#     "md5": "2f0c13f4ab6c9e3a8ddd17562ba4806c",
#     "relpath": "train/cats/cat.137.jpg"
#   },
#   {
#     "md5": "e45101b638f7d2f103983901428b16ea",
#     "relpath": "train/cats/cat.138.jpg"
#   },
#   {
#     "md5": "11cdb0324f7e160d5ffc3e2460d823ff",
#     "relpath": "train/cats/cat.139.jpg"
#   },
#   {
#     "md5": "da469e10cb8b8bdbbae34afe124495e3",
#     "relpath": "train/cats/cat.14.jpg"
#   },
#   {
#     "md5": "caffd52fbc3831a90cac908e7a87f34c",
#     "relpath": "train/cats/cat.140.jpg"
#   },
#   {
#     "md5": "55bf0471fa58284396ee3be2a75155f9",
#     "relpath": "train/cats/cat.141.jpg"
#   },
#   {
#     "md5": "8168515a4168d5ed569cf1c1c8dd160c",
#     "relpath": "train/cats/cat.142.jpg"
#   },
#   {
#     "md5": "fa9c1c08deb31279638c20d115d9557a",
#     "relpath": "train/cats/cat.143.jpg"
#   },
#   {
#     "md5": "d3f303a643e4aac396825504688d98ec",
#     "relpath": "train/cats/cat.144.jpg"
#   },
#   {
#     "md5": "5fe579a4dda9874b2952e30677fa1298",
#     "relpath": "train/cats/cat.145.jpg"
#   },
#   {
#     "md5": "af0b548cd3224aa7af7bd7a88e8e83be",
#     "relpath": "train/cats/cat.146.jpg"
#   },
#   {
#     "md5": "598ff30ba41ee6cb162f36218f2452f7",
#     "relpath": "train/cats/cat.147.jpg"
#   },
#   {
#     "md5": "dca808bd6985bce5a212641a45b95ac3",
#     "relpath": "train/cats/cat.148.jpg"
#   },
#   {
#     "md5": "7a7979ea7f945c824638e8163a97c101",
#     "relpath": "train/cats/cat.149.jpg"
#   },
#   {
#     "md5": "6688f74fd4a81c091ebf1ba309a53f7d",
#     "relpath": "train/cats/cat.15.jpg"
#   },
#   {
#     "md5": "ea1881c7f6d438173f01631d14ee2e92",
#     "relpath": "train/cats/cat.150.jpg"
#   },
#   {
#     "md5": "3a7a4e6e93d9093680e65c5163431d2f",
#     "relpath": "train/cats/cat.151.jpg"
#   },
#   {
#     "md5": "9e66a96d1264e9a56871c52d9a5f0917",
#     "relpath": "train/cats/cat.152.jpg"
#   },
#   {
#     "md5": "3904e165e1b95f69e11539f221530903",
#     "relpath": "train/cats/cat.153.jpg"
#   },
#   {
#     "md5": "712638fe2427d2a5beaba59ce6d34ae2",
#     "relpath": "train/cats/cat.154.jpg"
#   },
#   {
#     "md5": "647035c479d628b91e673d2643d481d6",
#     "relpath": "train/cats/cat.155.jpg"
#   },
#   {
#     "md5": "8fddaaeb3ce9c18cfb44b8f889fffc66",
#     "relpath": "train/cats/cat.156.jpg"
#   },
#   {
#     "md5": "db61ba421198db968906fa0e6b43ad4f",
#     "relpath": "train/cats/cat.157.jpg"
#   },
#   {
#     "md5": "5643f8e876e4a057c6951729ed13e511",
#     "relpath": "train/cats/cat.158.jpg"
#   },
#   {
#     "md5": "a096e395721aaa4d43e6c741ff95cbf4",
#     "relpath": "train/cats/cat.159.jpg"
#   },
#   {
#     "md5": "8bfb05364780f36d6c0eac49debe55ec",
#     "relpath": "train/cats/cat.16.jpg"
#   },
#   {
#     "md5": "0743f97dd826cba3599ac5afb02fea3a",
#     "relpath": "train/cats/cat.160.jpg"
#   },
#   {
#     "md5": "2c4043f05906740bc8e6ed3832da244c",
#     "relpath": "train/cats/cat.161.jpg"
#   },
#   {
#     "md5": "2310fbb5b555227df34157b2fd3aa102",
#     "relpath": "train/cats/cat.162.jpg"
#   },
#   {
#     "md5": "b5f17dcab2caaa7028140f82633311b6",
#     "relpath": "train/cats/cat.163.jpg"
#   },
#   {
#     "md5": "2acfab4efeeb9203f58144d050a1ee86",
#     "relpath": "train/cats/cat.164.jpg"
#   },
#   {
#     "md5": "f91a11a0f403c37cffa069cd5fea81a3",
#     "relpath": "train/cats/cat.165.jpg"
#   },
#   {
#     "md5": "33ed22b70de116807fdfd28fb3ca9000",
#     "relpath": "train/cats/cat.166.jpg"
#   },
#   {
#     "md5": "d071eef61286f45408d4702ced1d817a",
#     "relpath": "train/cats/cat.167.jpg"
#   },
#   {
#     "md5": "3c158f5803f5034c1d5b285dcdcd14ab",
#     "relpath": "train/cats/cat.168.jpg"
#   },
#   {
#     "md5": "1670434cce32d8ef992278c84488f37c",
#     "relpath": "train/cats/cat.169.jpg"
#   },
#   {
#     "md5": "1b16f61c243097c23671166b2ff488ee",
#     "relpath": "train/cats/cat.17.jpg"
#   },
#   {
#     "md5": "d93b9cdfd176d4142d6c82ecef1071cf",
#     "relpath": "train/cats/cat.170.jpg"
#   },
#   {
#     "md5": "171b9f278c104834705eff9c8ead7f26",
#     "relpath": "train/cats/cat.171.jpg"
#   },
#   {
#     "md5": "7bf5f435a0ae1a7690cfec899bd1e928",
#     "relpath": "train/cats/cat.172.jpg"
#   },
#   {
#     "md5": "0b9f1cc1ecf53f95eeadc66eff55f2a1",
#     "relpath": "train/cats/cat.173.jpg"
#   },
#   {
#     "md5": "36b58eb03714709542aa795ff40876c7",
#     "relpath": "train/cats/cat.174.jpg"
#   },
#   {
#     "md5": "24f90eae8663be1da79d291241655c20",
#     "relpath": "train/cats/cat.175.jpg"
#   },
#   {
#     "md5": "1322195355b5099bcfeb70ce1c01676d",
#     "relpath": "train/cats/cat.176.jpg"
#   },
#   {
#     "md5": "9ee80d013fa9a6ba8e7c8a8a8d2e882b",
#     "relpath": "train/cats/cat.177.jpg"
#   },
#   {
#     "md5": "4f157d51ad6192f668b1e740d70401df",
#     "relpath": "train/cats/cat.178.jpg"
#   },
#   {
#     "md5": "30b4e80fff81eddbe139efd25c53929c",
#     "relpath": "train/cats/cat.179.jpg"
#   },
#   {
#     "md5": "6f248f9132699c2d91a363cef44c5fb0",
#     "relpath": "train/cats/cat.18.jpg"
#   },
#   {
#     "md5": "a7cb18608a4d16338088e8ca53272c95",
#     "relpath": "train/cats/cat.180.jpg"
#   },
#   {
#     "md5": "1a3b1163638c98e1e6b0e1e9c3385e45",
#     "relpath": "train/cats/cat.181.jpg"
#   },
#   {
#     "md5": "071fd2e34397d4cd009f1914515b7ab0",
#     "relpath": "train/cats/cat.182.jpg"
#   },
#   {
#     "md5": "c6c014752e3fcbe8a41b18f902ee8a91",
#     "relpath": "train/cats/cat.183.jpg"
#   },
#   {
#     "md5": "4d617604cce7868466685da4369db18d",
#     "relpath": "train/cats/cat.184.jpg"
#   },
#   {
#     "md5": "4ca4d19cef7289db0306cf3806066b5e",
#     "relpath": "train/cats/cat.185.jpg"
#   },
#   {
#     "md5": "1a2fe77e2914e5922d1fab96c14fba3c",
#     "relpath": "train/cats/cat.186.jpg"
#   },
#   {
#     "md5": "5e4ef7f38e644946279d5c05d35e9530",
#     "relpath": "train/cats/cat.187.jpg"
#   },
#   {
#     "md5": "e0c3193bdee0a25bd3c93470bfba097d",
#     "relpath": "train/cats/cat.188.jpg"
#   },
#   {
#     "md5": "8d560b808ebe346d544e432b23350586",
#     "relpath": "train/cats/cat.189.jpg"
#   },
#   {
#     "md5": "ed6b111b896abf281fd64c7d6c8fd3c5",
#     "relpath": "train/cats/cat.19.jpg"
#   },
#   {
#     "md5": "9ef9ce80d05ffb371486ddc6c45943c1",
#     "relpath": "train/cats/cat.190.jpg"
#   },
#   {
#     "md5": "76deb50934fd162a8410dc9e2cc8e911",
#     "relpath": "train/cats/cat.191.jpg"
#   },
#   {
#     "md5": "8d866b8cd84bed37f4effadbe21dca49",
#     "relpath": "train/cats/cat.192.jpg"
#   },
#   {
#     "md5": "2c6ee24f1017f975838d024078598bb9",
#     "relpath": "train/cats/cat.193.jpg"
#   },
#   {
#     "md5": "d9e187ad15f3212debd0028962607832",
#     "relpath": "train/cats/cat.194.jpg"
#   },
#   {
#     "md5": "ff0e4379a1131c4e49d651a426d3e35c",
#     "relpath": "train/cats/cat.195.jpg"
#   },
#   {
#     "md5": "a5abf0d1deabc2bc5ca8c37cb77be56c",
#     "relpath": "train/cats/cat.196.jpg"
#   },
#   {
#     "md5": "50c0fc49da51638db03734400eb2ae20",
#     "relpath": "train/cats/cat.197.jpg"
#   },
#   {
#     "md5": "439fb4f2e8e0e7271995a4b9577858ce",
#     "relpath": "train/cats/cat.198.jpg"
#   },
#   {
#     "md5": "57dac42351b40b773c121ab024e4d69d",
#     "relpath": "train/cats/cat.199.jpg"
#   },
#   {
#     "md5": "504417d73bdf859125e7598b8cda163c",
#     "relpath": "train/cats/cat.2.jpg"
#   },
#   {
#     "md5": "ef336e7651c9e01fa04ba05d1e15ba34",
#     "relpath": "train/cats/cat.20.jpg"
#   },
#   {
#     "md5": "4add3c97fed1ba58b6c82d825e392ad1",
#     "relpath": "train/cats/cat.200.jpg"
#   },
#   {
#     "md5": "f6855f31064a245a702dd121af1b89d6",
#     "relpath": "train/cats/cat.201.jpg"
#   },
#   {
#     "md5": "bec37ee34f72e10de8d101f405bd0c7a",
#     "relpath": "train/cats/cat.202.jpg"
#   },
#   {
#     "md5": "0d0164d16be6ffe6b27c47e20671d8cd",
#     "relpath": "train/cats/cat.203.jpg"
#   },
#   {
#     "md5": "af7d6bb5ed876ca72ba9617ec1382ca4",
#     "relpath": "train/cats/cat.204.jpg"
#   },
#   {
#     "md5": "a5431d85bd13c72b18711d525ec74a08",
#     "relpath": "train/cats/cat.205.jpg"
#   },
#   {
#     "md5": "5129406d64fa1637d46051af267b0285",
#     "relpath": "train/cats/cat.206.jpg"
#   },
#   {
#     "md5": "8ba45e3fe11fe0520b9cadd2e0bbff5b",
#     "relpath": "train/cats/cat.207.jpg"
#   },
#   {
#     "md5": "5d33f63e542d655323da8d662244a662",
#     "relpath": "train/cats/cat.208.jpg"
#   },
#   {
#     "md5": "579d4a7dd0794c9d10e18320de017435",
#     "relpath": "train/cats/cat.209.jpg"
#   },
#   {
#     "md5": "5c278942057ee018c9b6f725345abf8b",
#     "relpath": "train/cats/cat.21.jpg"
#   },
#   {
#     "md5": "768aa87985a9c0bfcb3ab7799d39ef25",
#     "relpath": "train/cats/cat.210.jpg"
#   },
#   {
#     "md5": "14ae4fbd629e03a576f2a9863f0a4caa",
#     "relpath": "train/cats/cat.211.jpg"
#   },
#   {
#     "md5": "74d2409b9bab83d624152ae2f8184e33",
#     "relpath": "train/cats/cat.212.jpg"
#   },
#   {
#     "md5": "f460baaf2fbc1c0afa139e9990627dfb",
#     "relpath": "train/cats/cat.213.jpg"
#   },
#   {
#     "md5": "ebe2e20ecebac86fa768b389508ccbc3",
#     "relpath": "train/cats/cat.214.jpg"
#   },
#   {
#     "md5": "fa34dc45b60f43a8e2e36c6c87e5b7f6",
#     "relpath": "train/cats/cat.215.jpg"
#   },
#   {
#     "md5": "c03276d0699c3381313846aca0319fec",
#     "relpath": "train/cats/cat.216.jpg"
#   },
#   {
#     "md5": "42217fc35158fbed3801491a167677c8",
#     "relpath": "train/cats/cat.217.jpg"
#   },
#   {
#     "md5": "cae5eb2f35e1c80d3636fc8819c02482",
#     "relpath": "train/cats/cat.218.jpg"
#   },
#   {
#     "md5": "33270b448514295613edaaa1e6ed05e0",
#     "relpath": "train/cats/cat.219.jpg"
#   },
#   {
#     "md5": "8c5326cb12128917636d2a0f94f0b1e9",
#     "relpath": "train/cats/cat.22.jpg"
#   },
#   {
#     "md5": "0d379b7434a33de10a2d4bb153f750b2",
#     "relpath": "train/cats/cat.220.jpg"
#   },
#   {
#     "md5": "47254322670087e7cbb7a23b75c77e0a",
#     "relpath": "train/cats/cat.221.jpg"
#   },
#   {
#     "md5": "8bdcf6b8c5c7f07f2998077ba2896933",
#     "relpath": "train/cats/cat.222.jpg"
#   },
#   {
#     "md5": "ff1b28f260da7366d00c98d83bf5a892",
#     "relpath": "train/cats/cat.223.jpg"
#   },
#   {
#     "md5": "8741f714960ea5d549b8de1895ab891a",
#     "relpath": "train/cats/cat.224.jpg"
#   },
#   {
#     "md5": "75d8773d8e18a90f48e2b810525040f7",
#     "relpath": "train/cats/cat.225.jpg"
#   },
#   {
#     "md5": "854c3741571769401da37e9997ffbadb",
#     "relpath": "train/cats/cat.226.jpg"
#   },
#   {
#     "md5": "70d0b1eafc5285aad11ffbd666491a35",
#     "relpath": "train/cats/cat.227.jpg"
#   },
#   {
#     "md5": "f7dc66dc2bae6483aa04c0fe729405e9",
#     "relpath": "train/cats/cat.228.jpg"
#   },
#   {
#     "md5": "6d193065a5496ed9a07223121ad70f06",
#     "relpath": "train/cats/cat.229.jpg"
#   },
#   {
#     "md5": "b7a77a07855d5c36e75269c26ebdcf51",
#     "relpath": "train/cats/cat.23.jpg"
#   },
#   {
#     "md5": "65a5d80cc205e8812bb65784756311a4",
#     "relpath": "train/cats/cat.230.jpg"
#   },
#   {
#     "md5": "2d9a09cf12952e6126a36bef5529b711",
#     "relpath": "train/cats/cat.231.jpg"
#   },
#   {
#     "md5": "4d56b4d2776bb6cd4ee866d46fa89960",
#     "relpath": "train/cats/cat.232.jpg"
#   },
#   {
#     "md5": "6f73db27618f40c27bc6e494e1634b90",
#     "relpath": "train/cats/cat.233.jpg"
#   },
#   {
#     "md5": "93e57b90f26437aa5278f82599e323cf",
#     "relpath": "train/cats/cat.234.jpg"
#   },
#   {
#     "md5": "49d39a26733872d1a6abbb064e13367b",
#     "relpath": "train/cats/cat.235.jpg"
#   },
#   {
#     "md5": "bb3cf605b83074b83eafe2c0a8839688",
#     "relpath": "train/cats/cat.236.jpg"
#   },
#   {
#     "md5": "d905362812ec69120c55a959c614023d",
#     "relpath": "train/cats/cat.237.jpg"
#   },
#   {
#     "md5": "bc768529da5aac3d6016c58df99931c9",
#     "relpath": "train/cats/cat.238.jpg"
#   },
#   {
#     "md5": "71cee515c93d33dd0bfa146ba2e1d6a2",
#     "relpath": "train/cats/cat.239.jpg"
#   },
#   {
#     "md5": "cee961d797a3fd4902820ddf11ef726d",
#     "relpath": "train/cats/cat.24.jpg"
#   },
#   {
#     "md5": "a3946e9ca8ed29586922acc42d23187e",
#     "relpath": "train/cats/cat.240.jpg"
#   },
#   {
#     "md5": "3224faef395eaa3b4dfcf68e11830b3a",
#     "relpath": "train/cats/cat.241.jpg"
#   },
#   {
#     "md5": "3c2969e69fea770b64468966ca531f14",
#     "relpath": "train/cats/cat.242.jpg"
#   },
#   {
#     "md5": "be625c7ea88f0e268505a2e277479db4",
#     "relpath": "train/cats/cat.243.jpg"
#   },
#   {
#     "md5": "031b30150f1b14fc706fb0f5fa5ea008",
#     "relpath": "train/cats/cat.244.jpg"
#   },
#   {
#     "md5": "89ac02281d48e3924329fbee52479fa5",
#     "relpath": "train/cats/cat.245.jpg"
#   },
#   {
#     "md5": "4fcbbd9e08b8f49e86ef079d9a5f01af",
#     "relpath": "train/cats/cat.246.jpg"
#   },
#   {
#     "md5": "28eb38c87de533edca498e0c1551bafc",
#     "relpath": "train/cats/cat.247.jpg"
#   },
#   {
#     "md5": "29a99259178e9bba26db9b5c0731a5fb",
#     "relpath": "train/cats/cat.248.jpg"
#   },
#   {
#     "md5": "52f019f2f67740452d6d301223381faa",
#     "relpath": "train/cats/cat.249.jpg"
#   },
#   {
#     "md5": "8f7130c48d4f22cca29be2d29af7c762",
#     "relpath": "train/cats/cat.25.jpg"
#   },
#   {
#     "md5": "85d171b5a9faf996574c5a06afbd8e06",
#     "relpath": "train/cats/cat.250.jpg"
#   },
#   {
#     "md5": "17de7a6e575b06380479034036e10285",
#     "relpath": "train/cats/cat.251.jpg"
#   },
#   {
#     "md5": "73852ea6897b7be6f078b3f4a6010818",
#     "relpath": "train/cats/cat.252.jpg"
#   },
#   {
#     "md5": "7010d6f734130f0a42f02ff591f4f443",
#     "relpath": "train/cats/cat.253.jpg"
#   },
#   {
#     "md5": "d3ecb1a0e9dee4628482e3fbc9e7befb",
#     "relpath": "train/cats/cat.254.jpg"
#   },
#   {
#     "md5": "541dd3f23015ce027a7c4b5a4b7e10ee",
#     "relpath": "train/cats/cat.255.jpg"
#   },
#   {
#     "md5": "977b0d8228718039c0750f10211a1cc2",
#     "relpath": "train/cats/cat.256.jpg"
#   },
#   {
#     "md5": "83e01572cea6f08244d8b7fc7f934391",
#     "relpath": "train/cats/cat.257.jpg"
#   },
#   {
#     "md5": "ffa63a3ed3744154a3e9a20b72c9c2ce",
#     "relpath": "train/cats/cat.258.jpg"
#   },
#   {
#     "md5": "714502943c7fd4ffafa112a3f1c91de6",
#     "relpath": "train/cats/cat.259.jpg"
#   },
#   {
#     "md5": "2e53fb81aafd7178cb222369547be66b",
#     "relpath": "train/cats/cat.26.jpg"
#   },
#   {
#     "md5": "30ba93ec6eb869d68f022d41ec99326b",
#     "relpath": "train/cats/cat.260.jpg"
#   },
#   {
#     "md5": "e25af0c7aa6c77497dc13a75aa447158",
#     "relpath": "train/cats/cat.261.jpg"
#   },
#   {
#     "md5": "088119f65b249e86b77d7d8be9eae02d",
#     "relpath": "train/cats/cat.262.jpg"
#   },
#   {
#     "md5": "b6efd10ab38ff17fa593e3b102d088ac",
#     "relpath": "train/cats/cat.263.jpg"
#   },
#   {
#     "md5": "e75b50ec2914ff566a2d2cc28a17fa7a",
#     "relpath": "train/cats/cat.264.jpg"
#   },
#   {
#     "md5": "20298bd42a098e45c94d2405a11bec8e",
#     "relpath": "train/cats/cat.265.jpg"
#   },
#   {
#     "md5": "265313d85099cc10ee3bb7be6ab8e7b3",
#     "relpath": "train/cats/cat.266.jpg"
#   },
#   {
#     "md5": "f5c50cf1e933e98eb5c2b5c3bc22089e",
#     "relpath": "train/cats/cat.267.jpg"
#   },
#   {
#     "md5": "34399ab36ff7abaf695428f02737a3c5",
#     "relpath": "train/cats/cat.268.jpg"
#   },
#   {
#     "md5": "3359207adaba222942d6d8fc23fa5a45",
#     "relpath": "train/cats/cat.269.jpg"
#   },
#   {
#     "md5": "6a982353e8a10ee1b566881cb6840c41",
#     "relpath": "train/cats/cat.27.jpg"
#   },
#   {
#     "md5": "971f2e7c052dd8be0ac92ccebafb839b",
#     "relpath": "train/cats/cat.270.jpg"
#   },
#   {
#     "md5": "07572fabecb3f421c98186037792d1b6",
#     "relpath": "train/cats/cat.271.jpg"
#   },
#   {
#     "md5": "28f16da60b53facbfcf7d243b718026c",
#     "relpath": "train/cats/cat.272.jpg"
#   },
#   {
#     "md5": "fd553982d6ab6fc668b095460a2dacaa",
#     "relpath": "train/cats/cat.273.jpg"
#   },
#   {
#     "md5": "f983166a008c86f860adc972d26bf60e",
#     "relpath": "train/cats/cat.274.jpg"
#   },
#   {
#     "md5": "a00d095758c77e4a08f2475c77f5eb74",
#     "relpath": "train/cats/cat.275.jpg"
#   },
#   {
#     "md5": "24b01009a8d1ca0863315288e8eb92e8",
#     "relpath": "train/cats/cat.276.jpg"
#   },
#   {
#     "md5": "844b888882b8d98df147be2eacf0b868",
#     "relpath": "train/cats/cat.277.jpg"
#   },
#   {
#     "md5": "c5a634ba8d8c74f26b03441f9640c065",
#     "relpath": "train/cats/cat.278.jpg"
#   },
#   {
#     "md5": "3629651514591ab10e865d3d1730ab6d",
#     "relpath": "train/cats/cat.279.jpg"
#   },
#   {
#     "md5": "5e0c800f0c076dd9c75dc776a4e9ccf0",
#     "relpath": "train/cats/cat.28.jpg"
#   },
#   {
#     "md5": "2704c36e633ad601f1cd532d727c732b",
#     "relpath": "train/cats/cat.280.jpg"
#   },
#   {
#     "md5": "e410a796421d5eafe8f02474dce335b8",
#     "relpath": "train/cats/cat.281.jpg"
#   },
#   {
#     "md5": "e8c2bbb86818688b7477a5d332616136",
#     "relpath": "train/cats/cat.282.jpg"
#   },
#   {
#     "md5": "9362dc31825a671c5ac1f6961836b258",
#     "relpath": "train/cats/cat.283.jpg"
#   },
#   {
#     "md5": "44ff70078f8167f17552088b1e55ad8a",
#     "relpath": "train/cats/cat.284.jpg"
#   },
#   {
#     "md5": "e7a2a5056ed7d070ced65c78c0418e2e",
#     "relpath": "train/cats/cat.285.jpg"
#   },
#   {
#     "md5": "8f3160fc28addea70891ba3d131921aa",
#     "relpath": "train/cats/cat.286.jpg"
#   },
#   {
#     "md5": "ff5766bddeb178345f91a0b179a30d31",
#     "relpath": "train/cats/cat.287.jpg"
#   },
#   {
#     "md5": "c058894d20d6de8ba002e94962e1017e",
#     "relpath": "train/cats/cat.288.jpg"
#   },
#   {
#     "md5": "91f8a36086b1c6a788dd4040daf404cf",
#     "relpath": "train/cats/cat.289.jpg"
#   },
#   {
#     "md5": "01a1b4d05da28e7d501dedf708e0ea86",
#     "relpath": "train/cats/cat.29.jpg"
#   },
#   {
#     "md5": "9bf731449ce2eae4b7753b5d756fa051",
#     "relpath": "train/cats/cat.290.jpg"
#   },
#   {
#     "md5": "b2b4d9b9711a3d11c0c817f4f6dc796f",
#     "relpath": "train/cats/cat.291.jpg"
#   },
#   {
#     "md5": "86f540f81f87a127f8d40d752db1f5d8",
#     "relpath": "train/cats/cat.292.jpg"
#   },
#   {
#     "md5": "68aaa16211e227136a158cef125ecb05",
#     "relpath": "train/cats/cat.293.jpg"
#   },
#   {
#     "md5": "bce65290101b8bc5ac3b8f4c095f235f",
#     "relpath": "train/cats/cat.294.jpg"
#   },
#   {
#     "md5": "eeb2d30ec245fd937e412e917cfef3a9",
#     "relpath": "train/cats/cat.295.jpg"
#   },
#   {
#     "md5": "94b6e7d06149325895484a779b478e7e",
#     "relpath": "train/cats/cat.296.jpg"
#   },
#   {
#     "md5": "30537b4a64fb1032c06cc166a949efe3",
#     "relpath": "train/cats/cat.297.jpg"
#   },
#   {
#     "md5": "944a69770164666a29c5e59971a1a76c",
#     "relpath": "train/cats/cat.298.jpg"
#   },
#   {
#     "md5": "82600af7fd98b2df06005bcd6ee0dd0f",
#     "relpath": "train/cats/cat.299.jpg"
#   },
#   {
#     "md5": "da8f3afd184503f79e06ee631464f35a",
#     "relpath": "train/cats/cat.3.jpg"
#   },
#   {
#     "md5": "d3fa0ec30c7cabe62808786781c1d216",
#     "relpath": "train/cats/cat.30.jpg"
#   },
#   {
#     "md5": "303e60171c5560947e11e632a1585a7c",
#     "relpath": "train/cats/cat.300.jpg"
#   },
#   {
#     "md5": "83e42c0cf7029144f7c46f2d02ea6e72",
#     "relpath": "train/cats/cat.301.jpg"
#   },
#   {
#     "md5": "61875844c3568c27c494fc17a1dd0d05",
#     "relpath": "train/cats/cat.302.jpg"
#   },
#   {
#     "md5": "2571647791ae90ecc2fd5ff89a4d6404",
#     "relpath": "train/cats/cat.303.jpg"
#   },
#   {
#     "md5": "327594f96e96c6f64a6230f54313c73e",
#     "relpath": "train/cats/cat.304.jpg"
#   },
#   {
#     "md5": "f1c4f56e08cf929c91371c64987dd074",
#     "relpath": "train/cats/cat.305.jpg"
#   },
#   {
#     "md5": "f34f03c9ce7a6e2a4a010d586b5d3ef2",
#     "relpath": "train/cats/cat.306.jpg"
#   },
#   {
#     "md5": "9d5fe25bbce61a4af7d308ef3b22888d",
#     "relpath": "train/cats/cat.307.jpg"
#   },
#   {
#     "md5": "7cc2f00b55422ae700a35bd362474206",
#     "relpath": "train/cats/cat.308.jpg"
#   },
#   {
#     "md5": "30ff9057bb2de86a01e27f17ebc7660e",
#     "relpath": "train/cats/cat.309.jpg"
#   },
#   {
#     "md5": "c44cb81837c2f760eea7e398c7ee8c61",
#     "relpath": "train/cats/cat.31.jpg"
#   },
#   {
#     "md5": "8234a4e0f4f041d852b9c1b338d3b1a4",
#     "relpath": "train/cats/cat.310.jpg"
#   },
#   {
#     "md5": "0b7495f5d50e0ca9aeb9a0ff836e6fce",
#     "relpath": "train/cats/cat.311.jpg"
#   },
#   {
#     "md5": "1aea036df5f81f473001a65e614edda6",
#     "relpath": "train/cats/cat.312.jpg"
#   },
#   {
#     "md5": "b8d099e4730d1dac174a9d4a68817ce8",
#     "relpath": "train/cats/cat.313.jpg"
#   },
#   {
#     "md5": "b2eca1cec199b72c5194793ed5c7d9f4",
#     "relpath": "train/cats/cat.314.jpg"
#   },
#   {
#     "md5": "78bcac87d386306199b0b530746dc395",
#     "relpath": "train/cats/cat.315.jpg"
#   },
#   {
#     "md5": "f64b16194246a0918817e735f7530772",
#     "relpath": "train/cats/cat.316.jpg"
#   },
#   {
#     "md5": "3c38e14579a3bde214325dd494dc856e",
#     "relpath": "train/cats/cat.317.jpg"
#   },
#   {
#     "md5": "3dcb3d858d950f75d24ab89e43834835",
#     "relpath": "train/cats/cat.318.jpg"
#   },
#   {
#     "md5": "d7f102b620cf78a6bf18fe96ccba6c8f",
#     "relpath": "train/cats/cat.319.jpg"
#   },
#   {
#     "md5": "4bcc9522ce3cd7feb81fbcd6d3bdb9a3",
#     "relpath": "train/cats/cat.32.jpg"
#   },
#   {
#     "md5": "abe6da94d29efc7d59ece0c6d055d696",
#     "relpath": "train/cats/cat.320.jpg"
#   },
#   {
#     "md5": "f67abc5de60392b9d3e3467043787592",
#     "relpath": "train/cats/cat.321.jpg"
#   },
#   {
#     "md5": "ab06bc86fca79d46f4c72609c7e6b855",
#     "relpath": "train/cats/cat.322.jpg"
#   },
#   {
#     "md5": "86e7ece5c2468ab2920230f9c2590116",
#     "relpath": "train/cats/cat.323.jpg"
#   },
#   {
#     "md5": "b07647a2b0faf0980957515f00258103",
#     "relpath": "train/cats/cat.324.jpg"
#   },
#   {
#     "md5": "e47f1d73af50774f3aa1ef783ff397f1",
#     "relpath": "train/cats/cat.325.jpg"
#   },
#   {
#     "md5": "3ae30cd1b963d661c74259e639a3456a",
#     "relpath": "train/cats/cat.326.jpg"
#   },
#   {
#     "md5": "dd65428d63dfdf8cf6a582f4bf8f93d3",
#     "relpath": "train/cats/cat.327.jpg"
#   },
#   {
#     "md5": "6ea55dc917dbe34b32fe7c81af481645",
#     "relpath": "train/cats/cat.328.jpg"
#   },
#   {
#     "md5": "9a182a3e58be2d40e6b8bfa606046512",
#     "relpath": "train/cats/cat.329.jpg"
#   },
#   {
#     "md5": "0839e965cdf64f43b4e16b137a75bd1e",
#     "relpath": "train/cats/cat.33.jpg"
#   },
#   {
#     "md5": "f6dffd15e405a8389c5fe56956b842dc",
#     "relpath": "train/cats/cat.330.jpg"
#   },
#   {
#     "md5": "2f3f4a009a75f0280afc4eac93cd9905",
#     "relpath": "train/cats/cat.331.jpg"
#   },
#   {
#     "md5": "84e6298a12cf79b0539b3263d0e124f1",
#     "relpath": "train/cats/cat.332.jpg"
#   },
#   {
#     "md5": "cff6375372aa92b0edb5840259766b89",
#     "relpath": "train/cats/cat.333.jpg"
#   },
#   {
#     "md5": "a29185aef4176acfd091911a247e82e5",
#     "relpath": "train/cats/cat.334.jpg"
#   },
#   {
#     "md5": "4598d1ea6794db07186c572899de0d5b",
#     "relpath": "train/cats/cat.335.jpg"
#   },
#   {
#     "md5": "f11306da432eedd744cbe13fefe9ac41",
#     "relpath": "train/cats/cat.336.jpg"
#   },
#   {
#     "md5": "832fbc9f4d6a47a5d9ab606478876a9b",
#     "relpath": "train/cats/cat.337.jpg"
#   },
#   {
#     "md5": "5676c77a065ddb67ccdcd6a8e8407c7f",
#     "relpath": "train/cats/cat.338.jpg"
#   },
#   {
#     "md5": "2401d32551ac479ecbcdac98fc20cd09",
#     "relpath": "train/cats/cat.339.jpg"
#   },
#   {
#     "md5": "ce858c7ed1b5f4d4d8161a63f812b55a",
#     "relpath": "train/cats/cat.34.jpg"
#   },
#   {
#     "md5": "cf2815760e29a072496b1561d4318ae6",
#     "relpath": "train/cats/cat.340.jpg"
#   },
#   {
#     "md5": "643c4a2e1178f947d3515cfddcc53db8",
#     "relpath": "train/cats/cat.341.jpg"
#   },
#   {
#     "md5": "1b7c1458508d9d2a1dcfa34b71bf8bbd",
#     "relpath": "train/cats/cat.342.jpg"
#   },
#   {
#     "md5": "184c46fd5de80ab2ae4d494e3699af0e",
#     "relpath": "train/cats/cat.343.jpg"
#   },
#   {
#     "md5": "8e2e196717e5a5bf57890b404661e03e",
#     "relpath": "train/cats/cat.344.jpg"
#   },
#   {
#     "md5": "771b5a7df2147babc85aa8f4e103a820",
#     "relpath": "train/cats/cat.345.jpg"
#   },
#   {
#     "md5": "0ae2126498ea72e984b8618e4af02634",
#     "relpath": "train/cats/cat.346.jpg"
#   },
#   {
#     "md5": "4283b4b0aecff7b9e4cb468f49f0230d",
#     "relpath": "train/cats/cat.347.jpg"
#   },
#   {
#     "md5": "3667adfceba49ff24f3d8baebdae0f96",
#     "relpath": "train/cats/cat.348.jpg"
#   },
#   {
#     "md5": "50ab09a4fd378166ccb90a0ad7e7c7d8",
#     "relpath": "train/cats/cat.349.jpg"
#   },
#   {
#     "md5": "0cc0b3818199c9ba2d8c78a15f1b4cb8",
#     "relpath": "train/cats/cat.35.jpg"
#   },
#   {
#     "md5": "f0606c3cf2afa2a09219f029e75ede76",
#     "relpath": "train/cats/cat.350.jpg"
#   },
#   {
#     "md5": "253c6600034277482f69d2eac8db43b5",
#     "relpath": "train/cats/cat.351.jpg"
#   },
#   {
#     "md5": "01594e9de8897c6004469ea4916fceb5",
#     "relpath": "train/cats/cat.352.jpg"
#   },
#   {
#     "md5": "9bd368336cfa856fb714d1753212e759",
#     "relpath": "train/cats/cat.353.jpg"
#   },
#   {
#     "md5": "90a99fd1b5cfd8314944ff0c68e3a982",
#     "relpath": "train/cats/cat.354.jpg"
#   },
#   {
#     "md5": "a9dd67370e908259681d6a55069d1234",
#     "relpath": "train/cats/cat.355.jpg"
#   },
#   {
#     "md5": "22c4b331e1829ccfd93640186270e602",
#     "relpath": "train/cats/cat.356.jpg"
#   },
#   {
#     "md5": "52bb641eec27b79c3d96bc88251505d0",
#     "relpath": "train/cats/cat.357.jpg"
#   },
#   {
#     "md5": "3beb0800f15e1f7aa4637b9947634c95",
#     "relpath": "train/cats/cat.358.jpg"
#   },
#   {
#     "md5": "e43969bce9ca563a83910b01f029be15",
#     "relpath": "train/cats/cat.359.jpg"
#   },
#   {
#     "md5": "8bd3865db383c1fe4bf5e118821d6c18",
#     "relpath": "train/cats/cat.36.jpg"
#   },
#   {
#     "md5": "5af4d8e7173015cdfe063172e185adc2",
#     "relpath": "train/cats/cat.360.jpg"
#   },
#   {
#     "md5": "46d8e631cfa75ac90eed0b097b7f02b8",
#     "relpath": "train/cats/cat.361.jpg"
#   },
#   {
#     "md5": "5617b0b6bc1787a8d155d459e1b9d08d",
#     "relpath": "train/cats/cat.362.jpg"
#   },
#   {
#     "md5": "3629202f3f1a68a0ba91902bb5b9ccc9",
#     "relpath": "train/cats/cat.363.jpg"
#   },
#   {
#     "md5": "1030fad712bee57b3a8b526f17603c5f",
#     "relpath": "train/cats/cat.364.jpg"
#   },
#   {
#     "md5": "1070fdfb815eb8f90162a1c146a39921",
#     "relpath": "train/cats/cat.365.jpg"
#   },
#   {
#     "md5": "924bcd2586e39288d737ec3a2d1ce3ae",
#     "relpath": "train/cats/cat.366.jpg"
#   },
#   {
#     "md5": "7e460e5bee3acdd64c5ecef4a21b93af",
#     "relpath": "train/cats/cat.367.jpg"
#   },
#   {
#     "md5": "bb2c03a9dd50ff0f9b8a305e560208fa",
#     "relpath": "train/cats/cat.368.jpg"
#   },
#   {
#     "md5": "5664dd068aca9482909153620715b0ea",
#     "relpath": "train/cats/cat.369.jpg"
#   },
#   {
#     "md5": "2fd64c0babfb3334240d8244abb03ccc",
#     "relpath": "train/cats/cat.37.jpg"
#   },
#   {
#     "md5": "bbb3d0739b0f86282b4f02e3d1b7ea17",
#     "relpath": "train/cats/cat.370.jpg"
#   },
#   {
#     "md5": "a2e9647a2b08469edd1ea7b2cb15b49f",
#     "relpath": "train/cats/cat.371.jpg"
#   },
#   {
#     "md5": "2f6db38da91a6a8b6e268904e3a6df5a",
#     "relpath": "train/cats/cat.372.jpg"
#   },
#   {
#     "md5": "9238b89eace7b2109c6f3092426a45b4",
#     "relpath": "train/cats/cat.373.jpg"
#   },
#   {
#     "md5": "91ea59effbafba067258565acc58b456",
#     "relpath": "train/cats/cat.374.jpg"
#   },
#   {
#     "md5": "64e3f838c8df4877599785f24a57da1a",
#     "relpath": "train/cats/cat.375.jpg"
#   },
#   {
#     "md5": "bde1f8853277a3d1685d0b7cc46c69c2",
#     "relpath": "train/cats/cat.376.jpg"
#   },
#   {
#     "md5": "768f211574771416cad8dfc0ab76814d",
#     "relpath": "train/cats/cat.377.jpg"
#   },
#   {
#     "md5": "c1768e5fe1db30562e318f5e4d523f71",
#     "relpath": "train/cats/cat.378.jpg"
#   },
#   {
#     "md5": "d95958a260950026308293f56b4493a7",
#     "relpath": "train/cats/cat.379.jpg"
#   },
#   {
#     "md5": "bc356643e6950101560b15514ddd35be",
#     "relpath": "train/cats/cat.38.jpg"
#   },
#   {
#     "md5": "e281cef8a10050f10138978d823a32d3",
#     "relpath": "train/cats/cat.380.jpg"
#   },
#   {
#     "md5": "ff217e50d14538ab1172d8698fa3145f",
#     "relpath": "train/cats/cat.381.jpg"
#   },
#   {
#     "md5": "05f0dfac6821d7e228e362653c9f689c",
#     "relpath": "train/cats/cat.382.jpg"
#   },
#   {
#     "md5": "53fcfedb6d7b41196220d38c87d15cfc",
#     "relpath": "train/cats/cat.383.jpg"
#   },
#   {
#     "md5": "605bb9fe216d6542bfb1e11f6737f2a7",
#     "relpath": "train/cats/cat.384.jpg"
#   },
#   {
#     "md5": "2b667a952c3227ffc3b8e053c34d4225",
#     "relpath": "train/cats/cat.385.jpg"
#   },
#   {
#     "md5": "c97319961e3f69e930e63ca3b2329367",
#     "relpath": "train/cats/cat.386.jpg"
#   },
#   {
#     "md5": "2f102d922dabf50975b2f051e669d70b",
#     "relpath": "train/cats/cat.387.jpg"
#   },
#   {
#     "md5": "79e850c72cf12ec746b80b3a430e5846",
#     "relpath": "train/cats/cat.388.jpg"
#   },
#   {
#     "md5": "a20d41554cc7e83380f23d85a1205d66",
#     "relpath": "train/cats/cat.389.jpg"
#   },
#   {
#     "md5": "420de1ab9d9c6d6c1e2360d7b509147f",
#     "relpath": "train/cats/cat.39.jpg"
#   },
#   {
#     "md5": "6a8d20fa6ef0a5dcdf16b69c31f85d81",
#     "relpath": "train/cats/cat.390.jpg"
#   },
#   {
#     "md5": "7dca80a46d6ac69754709b0468f41e4f",
#     "relpath": "train/cats/cat.391.jpg"
#   },
#   {
#     "md5": "485cd31f899d45450833066fca842b99",
#     "relpath": "train/cats/cat.392.jpg"
#   },
#   {
#     "md5": "07cb4587064f03b8e2a3d1d743a37a63",
#     "relpath": "train/cats/cat.393.jpg"
#   },
#   {
#     "md5": "a95834b64f251ea6f8d68155457f5de1",
#     "relpath": "train/cats/cat.394.jpg"
#   },
#   {
#     "md5": "5e688c2960f47d6108e1ea5b3ede567a",
#     "relpath": "train/cats/cat.395.jpg"
#   },
#   {
#     "md5": "c7ff230523b9360f4fa17926e5e8e8f0",
#     "relpath": "train/cats/cat.396.jpg"
#   },
#   {
#     "md5": "fe6dfe2d7fc0954518b9132eda8991b7",
#     "relpath": "train/cats/cat.397.jpg"
#   },
#   {
#     "md5": "e021eea73aae49844b59ac50ae6d9404",
#     "relpath": "train/cats/cat.398.jpg"
#   },
#   {
#     "md5": "00ed28e821623e35210e83fbad6af8b4",
#     "relpath": "train/cats/cat.399.jpg"
#   },
#   {
#     "md5": "00f1acf458ae561796d9abf10e384f31",
#     "relpath": "train/cats/cat.4.jpg"
#   },
#   {
#     "md5": "efdfeb2517eb734347a8037efe3964cc",
#     "relpath": "train/cats/cat.40.jpg"
#   },
#   {
#     "md5": "f725ca9a9001c6902940e34780965799",
#     "relpath": "train/cats/cat.400.jpg"
#   },
#   {
#     "md5": "789e5c85c4f22957d98c511daaa680a3",
#     "relpath": "train/cats/cat.401.jpg"
#   },
#   {
#     "md5": "de373b319225966788c6c6721ab25258",
#     "relpath": "train/cats/cat.402.jpg"
#   },
#   {
#     "md5": "6f44d915e2db1487d0737f4ff65f0c15",
#     "relpath": "train/cats/cat.403.jpg"
#   },
#   {
#     "md5": "f5f529c7f49412f99bd30a29fdee0de2",
#     "relpath": "train/cats/cat.404.jpg"
#   },
#   {
#     "md5": "4d59c3a3a5f05ceb06abda5fe191f0e8",
#     "relpath": "train/cats/cat.405.jpg"
#   },
#   {
#     "md5": "d0c8d68b91a16460d0cc64bd886df86b",
#     "relpath": "train/cats/cat.406.jpg"
#   },
#   {
#     "md5": "349c3eed277414a1debfc4cce819e643",
#     "relpath": "train/cats/cat.407.jpg"
#   },
#   {
#     "md5": "f7b96745cf223046c0bf32dce86dc0f2",
#     "relpath": "train/cats/cat.408.jpg"
#   },
#   {
#     "md5": "882d6bbe0f01694cc9a0a8723021c07c",
#     "relpath": "train/cats/cat.409.jpg"
#   },
#   {
#     "md5": "a5de74a1673ee007c3ca7bd56fc36bb3",
#     "relpath": "train/cats/cat.41.jpg"
#   },
#   {
#     "md5": "549b6a78280c9ce7b34e6df036d56de1",
#     "relpath": "train/cats/cat.410.jpg"
#   },
#   {
#     "md5": "808d3035ba929ffa8b1da1359b52e0be",
#     "relpath": "train/cats/cat.411.jpg"
#   },
#   {
#     "md5": "48bffd7a22494e53166f537ceaeea469",
#     "relpath": "train/cats/cat.412.jpg"
#   },
#   {
#     "md5": "6e17b42b641fc6bd1a68400165895d90",
#     "relpath": "train/cats/cat.413.jpg"
#   },
#   {
#     "md5": "d3710e3be78400b2f8160a11094ee519",
#     "relpath": "train/cats/cat.414.jpg"
#   },
#   {
#     "md5": "7b12de261ca0f8dd32e910e0f5c08c63",
#     "relpath": "train/cats/cat.415.jpg"
#   },
#   {
#     "md5": "d5b89876365de2933198cc8e5e5d1710",
#     "relpath": "train/cats/cat.416.jpg"
#   },
#   {
#     "md5": "ab6b2a31de4a54738f9e035354e68a09",
#     "relpath": "train/cats/cat.417.jpg"
#   },
#   {
#     "md5": "d0d2dca834aa8ce2a4e2a324613b5fc3",
#     "relpath": "train/cats/cat.418.jpg"
#   },
#   {
#     "md5": "65c0b042ed531ea65435d0762c3ec739",
#     "relpath": "train/cats/cat.419.jpg"
#   },
#   {
#     "md5": "2a42f5e6491a937329a1074924e1e7c6",
#     "relpath": "train/cats/cat.42.jpg"
#   },
#   {
#     "md5": "3ae6079c2e7463513ba33d48a33e13b5",
#     "relpath": "train/cats/cat.420.jpg"
#   },
#   {
#     "md5": "f5c3ed699b2ebef7fb2e1d27acb6ce43",
#     "relpath": "train/cats/cat.421.jpg"
#   },
#   {
#     "md5": "a3d60a80999808b63ca8f3f63c07ad7f",
#     "relpath": "train/cats/cat.422.jpg"
#   },
#   {
#     "md5": "c8af93b1ceecb1852b50ecd7404bd4c5",
#     "relpath": "train/cats/cat.423.jpg"
#   },
#   {
#     "md5": "0e7e4f4624ea3d0844d0457deecdc498",
#     "relpath": "train/cats/cat.424.jpg"
#   },
#   {
#     "md5": "ef57629be045f76bd8467132419466b9",
#     "relpath": "train/cats/cat.425.jpg"
#   },
#   {
#     "md5": "b3e95b5e67ee48a28a00836e6d519a0f",
#     "relpath": "train/cats/cat.426.jpg"
#   },
#   {
#     "md5": "a483e13075b7ae4fcdda23b7a20d4345",
#     "relpath": "train/cats/cat.427.jpg"
#   },
#   {
#     "md5": "1bfba4171f600f3e6f7b9f9e2f98f69c",
#     "relpath": "train/cats/cat.428.jpg"
#   },
#   {
#     "md5": "c6ac0899ba22937a69bbfdf2a5d889a9",
#     "relpath": "train/cats/cat.429.jpg"
#   },
#   {
#     "md5": "a31177d933179463372a7ae6e8ce0be3",
#     "relpath": "train/cats/cat.43.jpg"
#   },
#   {
#     "md5": "44781666c2b5942a6a0eea3f00a82a75",
#     "relpath": "train/cats/cat.430.jpg"
#   },
#   {
#     "md5": "baef8802703ca363fc2a06bf054415a7",
#     "relpath": "train/cats/cat.431.jpg"
#   },
#   {
#     "md5": "405ae8af4ca5e6e8bd35ecb7e16e55fd",
#     "relpath": "train/cats/cat.432.jpg"
#   },
#   {
#     "md5": "dfa2cc4092e6fe2e80b08783e1d816e7",
#     "relpath": "train/cats/cat.433.jpg"
#   },
#   {
#     "md5": "042d3eb0280b3f4016cfd78c24190053",
#     "relpath": "train/cats/cat.434.jpg"
#   },
#   {
#     "md5": "3c6627b754531a693a88533ea8f3e1b9",
#     "relpath": "train/cats/cat.435.jpg"
#   },
#   {
#     "md5": "e1c0721ceeac21c92e528339e37820b5",
#     "relpath": "train/cats/cat.436.jpg"
#   },
#   {
#     "md5": "11465d55588f1d9c02bc2cc8f60395cf",
#     "relpath": "train/cats/cat.437.jpg"
#   },
#   {
#     "md5": "982ccfda9a41e6fd73371741037ae054",
#     "relpath": "train/cats/cat.438.jpg"
#   },
#   {
#     "md5": "8ec371c01ace17ff66c91de5d6b8f610",
#     "relpath": "train/cats/cat.439.jpg"
#   },
#   {
#     "md5": "d1a558997681be930521db792a1a0bae",
#     "relpath": "train/cats/cat.44.jpg"
#   },
#   {
#     "md5": "1bebd63d318dc65f65be56129d0e29ba",
#     "relpath": "train/cats/cat.440.jpg"
#   },
#   {
#     "md5": "9e58171537c8c4c6bc4bd0ed70ccce5c",
#     "relpath": "train/cats/cat.441.jpg"
#   },
#   {
#     "md5": "57fabcecc74453d86e421dca027bf8d4",
#     "relpath": "train/cats/cat.442.jpg"
#   },
#   {
#     "md5": "82cccd0c3a380b99cf88efd1b945bfd4",
#     "relpath": "train/cats/cat.443.jpg"
#   },
#   {
#     "md5": "7826d70c9feda5607db2354e68426903",
#     "relpath": "train/cats/cat.444.jpg"
#   },
#   {
#     "md5": "6aafc9b5c470dd11017885afd6b57e6a",
#     "relpath": "train/cats/cat.445.jpg"
#   },
#   {
#     "md5": "9b584129536c5525fa862548c5243732",
#     "relpath": "train/cats/cat.446.jpg"
#   },
#   {
#     "md5": "201e5dbc96f8a9217c00a08cde2f7115",
#     "relpath": "train/cats/cat.447.jpg"
#   },
#   {
#     "md5": "c14a974e6c60ccd07f61487c644c6f87",
#     "relpath": "train/cats/cat.448.jpg"
#   },
#   {
#     "md5": "677b4c2ecb97e9bf19090fd3d972c822",
#     "relpath": "train/cats/cat.449.jpg"
#   },
#   {
#     "md5": "1dd81e317498a255767c22d8ea00ac9e",
#     "relpath": "train/cats/cat.45.jpg"
#   },
#   {
#     "md5": "03e24be05d32a5d32f838660e6f43b5f",
#     "relpath": "train/cats/cat.450.jpg"
#   },
#   {
#     "md5": "e0c437d3c99161f9170e13a7cfdf5e89",
#     "relpath": "train/cats/cat.451.jpg"
#   },
#   {
#     "md5": "debe6b2b75e83bfd5d8800ccfba6d611",
#     "relpath": "train/cats/cat.452.jpg"
#   },
#   {
#     "md5": "e00f9b2b325c7e0f48042d03cea54fa4",
#     "relpath": "train/cats/cat.453.jpg"
#   },
#   {
#     "md5": "4b7361b6ade0e4366cb1048fd0ee604f",
#     "relpath": "train/cats/cat.454.jpg"
#   },
#   {
#     "md5": "2bd0227e70e01bb6b41cc624a57f4e84",
#     "relpath": "train/cats/cat.455.jpg"
#   },
#   {
#     "md5": "e05947567a445c59c028c73614c840fd",
#     "relpath": "train/cats/cat.456.jpg"
#   },
#   {
#     "md5": "6396c8c00d8857f29b8850a10a7e9bd0",
#     "relpath": "train/cats/cat.457.jpg"
#   },
#   {
#     "md5": "0387c83de09a106be93dde768bcfe12f",
#     "relpath": "train/cats/cat.458.jpg"
#   },
#   {
#     "md5": "c650143a5628d8061252edccccf42963",
#     "relpath": "train/cats/cat.459.jpg"
#   },
#   {
#     "md5": "dea66ca1e4643cdfba5bffce59cbbc3d",
#     "relpath": "train/cats/cat.46.jpg"
#   },
#   {
#     "md5": "5585c2602fc8526878747400d1c1dea1",
#     "relpath": "train/cats/cat.460.jpg"
#   },
#   {
#     "md5": "e478b5a21f0a7fbcb57254ba87587214",
#     "relpath": "train/cats/cat.461.jpg"
#   },
#   {
#     "md5": "78e0e410a31d4d9cabdc616dadeac568",
#     "relpath": "train/cats/cat.462.jpg"
#   },
#   {
#     "md5": "e31e75886b7ce0de334330041677d1ca",
#     "relpath": "train/cats/cat.463.jpg"
#   },
#   {
#     "md5": "566ccb4b98cfd12ee222425dfd6c0c86",
#     "relpath": "train/cats/cat.464.jpg"
#   },
#   {
#     "md5": "241ddb4c3344587dc6754465df2d894c",
#     "relpath": "train/cats/cat.465.jpg"
#   },
#   {
#     "md5": "b591d09d8b124dbe9c985ab0dc1544e1",
#     "relpath": "train/cats/cat.466.jpg"
#   },
#   {
#     "md5": "a812b7349fabb9fd3b1d6d990ca8cd81",
#     "relpath": "train/cats/cat.467.jpg"
#   },
#   {
#     "md5": "e97e8ac2072896528797e0f9d9b13863",
#     "relpath": "train/cats/cat.468.jpg"
#   },
#   {
#     "md5": "75863161fc7cfe96a3cba39a3882c204",
#     "relpath": "train/cats/cat.469.jpg"
#   },
#   {
#     "md5": "0880b2fb13e04b074816ffa5f1db7058",
#     "relpath": "train/cats/cat.47.jpg"
#   },
#   {
#     "md5": "d31c301fed6a334f9405411f388c8afc",
#     "relpath": "train/cats/cat.470.jpg"
#   },
#   {
#     "md5": "7a4acfc0411ad99bb6de6ee6ba98c8a7",
#     "relpath": "train/cats/cat.471.jpg"
#   },
#   {
#     "md5": "5016fd4847746e0fee713654d707e745",
#     "relpath": "train/cats/cat.472.jpg"
#   },
#   {
#     "md5": "422b1bc84fb276136854adeca208f62a",
#     "relpath": "train/cats/cat.473.jpg"
#   },
#   {
#     "md5": "917736baa795f498f0431418aa779b32",
#     "relpath": "train/cats/cat.474.jpg"
#   },
#   {
#     "md5": "0d170f63f3db73b24e6779932ae80a46",
#     "relpath": "train/cats/cat.475.jpg"
#   },
#   {
#     "md5": "dcab6689a680d77cbd23858a78e630e0",
#     "relpath": "train/cats/cat.476.jpg"
#   },
#   {
#     "md5": "7a4bdcc96891f1b47b1e619a7610ac1b",
#     "relpath": "train/cats/cat.477.jpg"
#   },
#   {
#     "md5": "c2a63d8db45389763f938e8f630ee44a",
#     "relpath": "train/cats/cat.478.jpg"
#   },
#   {
#     "md5": "ec3a97d840c1e29a9b99ae073317726e",
#     "relpath": "train/cats/cat.479.jpg"
#   },
#   {
#     "md5": "158ba1434aa5c4a76a096d3874d2e88e",
#     "relpath": "train/cats/cat.48.jpg"
#   },
#   {
#     "md5": "ce9b8396f6c88e7f1f91456ae52de3de",
#     "relpath": "train/cats/cat.480.jpg"
#   },
#   {
#     "md5": "77f0bb6e85c0a75a0e1f7fb6fd89327e",
#     "relpath": "train/cats/cat.481.jpg"
#   },
#   {
#     "md5": "1ae0ede1e0b6ae7685ad54457e207e9f",
#     "relpath": "train/cats/cat.482.jpg"
#   },
#   {
#     "md5": "0e7600e65be16a564e69178ac344c7a3",
#     "relpath": "train/cats/cat.483.jpg"
#   },
#   {
#     "md5": "02122697e0da1cce8c89fe9de5ba96f5",
#     "relpath": "train/cats/cat.484.jpg"
#   },
#   {
#     "md5": "35b45fde88c8cbbf64e43b172d6f2418",
#     "relpath": "train/cats/cat.485.jpg"
#   },
#   {
#     "md5": "f1368759f8154b91a6d6226628a484be",
#     "relpath": "train/cats/cat.486.jpg"
#   },
#   {
#     "md5": "fc4d1584687d4509df6d0709da492ce9",
#     "relpath": "train/cats/cat.487.jpg"
#   },
#   {
#     "md5": "b50ca1c8138343cd36336d7e373f44d2",
#     "relpath": "train/cats/cat.488.jpg"
#   },
#   {
#     "md5": "38ea6714d78c0d1435d2badaf7cc50bf",
#     "relpath": "train/cats/cat.489.jpg"
#   },
#   {
#     "md5": "04f7d6d1ebf1214414fc07b3cf7f113e",
#     "relpath": "train/cats/cat.49.jpg"
#   },
#   {
#     "md5": "4cbfe77acf2ddf3601f83100b3eed8d5",
#     "relpath": "train/cats/cat.490.jpg"
#   },
#   {
#     "md5": "05e6e3e0dd07e3e450740170f346f0a0",
#     "relpath": "train/cats/cat.491.jpg"
#   },
#   {
#     "md5": "be5bcaad5831facc720f7e2ead5414a4",
#     "relpath": "train/cats/cat.492.jpg"
#   },
#   {
#     "md5": "aefd25b185746f4ca6773b519c432f03",
#     "relpath": "train/cats/cat.493.jpg"
#   },
#   {
#     "md5": "6e28345c777d089a0af66119c9a6b3dd",
#     "relpath": "train/cats/cat.494.jpg"
#   },
#   {
#     "md5": "34a6a72d5d7be766138669be9a74139f",
#     "relpath": "train/cats/cat.495.jpg"
#   },
#   {
#     "md5": "6e4499c542482e623f491433786f4d77",
#     "relpath": "train/cats/cat.496.jpg"
#   },
#   {
#     "md5": "b772a10c2e2016fe0363c6852e89a33c",
#     "relpath": "train/cats/cat.497.jpg"
#   },
#   {
#     "md5": "fbb04f8a02dfe974b2e2fca1640cf7f9",
#     "relpath": "train/cats/cat.498.jpg"
#   },
#   {
#     "md5": "73fb2d1d48d6c95d96ab3cf48ad79fcb",
#     "relpath": "train/cats/cat.499.jpg"
#   },
#   {
#     "md5": "d82bd0da3bd1b34e9c2b7babfc4d5220",
#     "relpath": "train/cats/cat.5.jpg"
#   },
#   {
#     "md5": "ba71a6c22bc5ec344e72fdff4d478e98",
#     "relpath": "train/cats/cat.50.jpg"
#   },
#   {
#     "md5": "1b32343db5af5f735e02d4ef7dbca604",
#     "relpath": "train/cats/cat.500.jpg"
#   },
#   {
#     "md5": "5cad5e8e4f615e8037f8b29f99fb28cf",
#     "relpath": "train/cats/cat.51.jpg"
#   },
#   {
#     "md5": "6cb2fc27da87691cb70c6bea47d12316",
#     "relpath": "train/cats/cat.52.jpg"
#   },
#   {
#     "md5": "3bc5a0918a0b9a7e974d31376b1fcf35",
#     "relpath": "train/cats/cat.53.jpg"
#   },
#   {
#     "md5": "ebdbbb348a67efcadc9c7ae2c63c488e",
#     "relpath": "train/cats/cat.54.jpg"
#   },
#   {
#     "md5": "5a1dc49649f36446c8c819b8c9f7c140",
#     "relpath": "train/cats/cat.55.jpg"
#   },
#   {
#     "md5": "4db2db41724f6c711a57ad30366cbbd3",
#     "relpath": "train/cats/cat.56.jpg"
#   },
#   {
#     "md5": "47e8183d4340c7e7576399812b4611e7",
#     "relpath": "train/cats/cat.57.jpg"
#   },
#   {
#     "md5": "e5164c24dd1c7e9a56c4baf34a5e8983",
#     "relpath": "train/cats/cat.58.jpg"
#   },
#   {
#     "md5": "394cb5029aa1f67256549076de0d4c9e",
#     "relpath": "train/cats/cat.59.jpg"
#   },
#   {
#     "md5": "ed61f9d036be07f7843327aaab614c4f",
#     "relpath": "train/cats/cat.6.jpg"
#   },
#   {
#     "md5": "4b8f3ddefe0b3484a2ee5e756e2abfd5",
#     "relpath": "train/cats/cat.60.jpg"
#   },
#   {
#     "md5": "ae0c25f1618e3ba74c5f581bf93f8580",
#     "relpath": "train/cats/cat.61.jpg"
#   },
#   {
#     "md5": "397c673fafb49f89c84b22f95a3853d0",
#     "relpath": "train/cats/cat.62.jpg"
#   },
#   {
#     "md5": "ca81707a315715f2ff597ed8d220f4c6",
#     "relpath": "train/cats/cat.63.jpg"
#   },
#   {
#     "md5": "550843e62b0fc6213f4dce824c3ea1df",
#     "relpath": "train/cats/cat.64.jpg"
#   },
#   {
#     "md5": "c6f5c8be38e0e076489434c43cc2f944",
#     "relpath": "train/cats/cat.65.jpg"
#   },
#   {
#     "md5": "98d69a2fee6813fb81ebeb7b142af4b5",
#     "relpath": "train/cats/cat.66.jpg"
#   },
#   {
#     "md5": "c55b6f16216b02bfea7bb2d4743e9992",
#     "relpath": "train/cats/cat.67.jpg"
#   },
#   {
#     "md5": "725ad8c5291da86da0e9f4cdd356e31d",
#     "relpath": "train/cats/cat.68.jpg"
#   },
#   {
#     "md5": "7b4becfd6e4eb7a375349c3907219156",
#     "relpath": "train/cats/cat.69.jpg"
#   },
#   {
#     "md5": "9833c9ebf6e616eb05b0b75e6a6c2354",
#     "relpath": "train/cats/cat.7.jpg"
#   },
#   {
#     "md5": "51ddcd39074f291b75643a7d34971264",
#     "relpath": "train/cats/cat.70.jpg"
#   },
#   {
#     "md5": "2ded69e368d157013b483710b57adc1a",
#     "relpath": "train/cats/cat.71.jpg"
#   },
#   {
#     "md5": "615bb7cebf1779b530f33b100d1f14b5",
#     "relpath": "train/cats/cat.72.jpg"
#   },
#   {
#     "md5": "a41109048bcd2e32f6d2f0b4feb8f3a8",
#     "relpath": "train/cats/cat.73.jpg"
#   },
#   {
#     "md5": "93c75546d8cf99a23b01741f28be797e",
#     "relpath": "train/cats/cat.74.jpg"
#   },
#   {
#     "md5": "d7aabe1d17884bad89281b6dab85877c",
#     "relpath": "train/cats/cat.75.jpg"
#   },
#   {
#     "md5": "19b029e37a86992274fb9b77b898a33b",
#     "relpath": "train/cats/cat.76.jpg"
#   },
#   {
#     "md5": "cb6eb8ecb823b99bb8d4392967454986",
#     "relpath": "train/cats/cat.77.jpg"
#   },
#   {
#     "md5": "68cce319fa44847699ce071b144e7f7d",
#     "relpath": "train/cats/cat.78.jpg"
#   },
#   {
#     "md5": "6265535ffb37ab8cb74cc19741e59d66",
#     "relpath": "train/cats/cat.79.jpg"
#   },
#   {
#     "md5": "2aaa011c71d9f8b6cb41c282c08abd83",
#     "relpath": "train/cats/cat.8.jpg"
#   },
#   {
#     "md5": "923a3982a201e9820e3a268734650a40",
#     "relpath": "train/cats/cat.80.jpg"
#   },
#   {
#     "md5": "1f9cee21ffef0d2768d6d605e00eaf8d",
#     "relpath": "train/cats/cat.81.jpg"
#   },
#   {
#     "md5": "9a4fdd417901b367d85d84ee745d4751",
#     "relpath": "train/cats/cat.82.jpg"
#   },
#   {
#     "md5": "a4667dba7b6fa071bbc075da3dae042d",
#     "relpath": "train/cats/cat.83.jpg"
#   },
#   {
#     "md5": "a9e8cdf57bd2118ca783a0fc5318083f",
#     "relpath": "train/cats/cat.84.jpg"
#   },
#   {
#     "md5": "db45e1fe3a01562af43d08e3e59cb5c7",
#     "relpath": "train/cats/cat.85.jpg"
#   },
#   {
#     "md5": "45d3c1b6f7a031b7be6503ebfe0e300f",
#     "relpath": "train/cats/cat.86.jpg"
#   },
#   {
#     "md5": "ff4087cc39b8142c71ded1f2d4b36fe6",
#     "relpath": "train/cats/cat.87.jpg"
#   },
#   {
#     "md5": "051496d3f6476b6596646089bda4bf21",
#     "relpath": "train/cats/cat.88.jpg"
#   },
#   {
#     "md5": "34d72f65194994de59481f904e54d2d1",
#     "relpath": "train/cats/cat.89.jpg"
#   },
#   {
#     "md5": "f057e119539685a8bdefee83821029ba",
#     "relpath": "train/cats/cat.9.jpg"
#   },
#   {
#     "md5": "101b29d9253f8161726f050904b89360",
#     "relpath": "train/cats/cat.90.jpg"
#   },
#   {
#     "md5": "feb1425321aafa0b6df8337732e11efb",
#     "relpath": "train/cats/cat.91.jpg"
#   },
#   {
#     "md5": "15e598e16c4a765ae92764ce8cd04fbe",
#     "relpath": "train/cats/cat.92.jpg"
#   },
#   {
#     "md5": "90cdec4ec37327f2fc34593e96a78680",
#     "relpath": "train/cats/cat.93.jpg"
#   },
#   {
#     "md5": "05f58dccf2a1be2296a64f6e0c9cc72c",
#     "relpath": "train/cats/cat.94.jpg"
#   },
#   {
#     "md5": "b41ed696b88ddabe12dbee38d338872d",
#     "relpath": "train/cats/cat.95.jpg"
#   },
#   {
#     "md5": "26b38eb86151045ea00c9e1a1613b031",
#     "relpath": "train/cats/cat.96.jpg"
#   },
#   {
#     "md5": "5aec0cf2b411286f4eb90322f27fd76f",
#     "relpath": "train/cats/cat.97.jpg"
#   },
#   {
#     "md5": "7bbe68a683dc9fa51f3ea6f949d52426",
#     "relpath": "train/cats/cat.98.jpg"
#   },
#   {
#     "md5": "9e89900c4c75abf40e35a0a567b25a75",
#     "relpath": "train/cats/cat.99.jpg"
#   },
#   {
#     "md5": "91c6063f96663a84cfa3d275cc903261",
#     "relpath": "train/dogs/dog.1.jpg"
#   },
#   {
# ...
#     "relpath": "validation/dogs/dog.1244.jpg"
#   },
#   {
#     "md5": "1f7a39a3634ed016a1ca96b427c60244",
#     "relpath": "validation/dogs/dog.1245.jpg"
#   },
#   {
#     "md5": "d684fa1ef732fdb30d8e9fb55e2c1cda",
#     "relpath": "validation/dogs/dog.1246.jpg"
#   },
#   {
#     "md5": "006413da232322e4b67f453543140eec",
#     "relpath": "validation/dogs/dog.1247.jpg"
#   },
#   {
#     "md5": "deba1a7a75998818238dba5127df1831",
#     "relpath": "validation/dogs/dog.1248.jpg"
#   },
#   {
#     "md5": "b0cf5e9880155368bf7f02455f3bf1e3",
#     "relpath": "validation/dogs/dog.1249.jpg"
#   },
#   {
#     "md5": "41d10b403624b5aa845d4a28f1c27d44",
#     "relpath": "validation/dogs/dog.1250.jpg"
#   },
#   {
#     "md5": "753e251a4f1024dcd63f80e7e07c8686",
#     "relpath": "validation/dogs/dog.1251.jpg"
#   },
#   {
#     "md5": "c4744734470603d37125562e6b15485e",
#     "relpath": "validation/dogs/dog.1252.jpg"
#   },
#   {
#     "md5": "2d0b19d9bbdb725c2b7a2afbc63115b4",
#     "relpath": "validation/dogs/dog.1253.jpg"
#   },
#   {
#     "md5": "c92608f4cd8dbf68dab3a30dce53cb11",
#     "relpath": "validation/dogs/dog.1254.jpg"
#   },
#   {
#     "md5": "e9e72ae09e026e48bc159372e2e6d540",
#     "relpath": "validation/dogs/dog.1255.jpg"
#   },
#   {
#     "md5": "8c4410ed40152e2b9dc157aca8ef4264",
#     "relpath": "validation/dogs/dog.1256.jpg"
#   },
#   {
#     "md5": "e1bf6dbe971de8047d0e7d0c1e111c56",
#     "relpath": "validation/dogs/dog.1257.jpg"
#   },
#   {
#     "md5": "565f04e9d5f4e2cf99d7091515a579cc",
#     "relpath": "validation/dogs/dog.1258.jpg"
#   },
#   {
#     "md5": "2862c9a15f12fb1a394223a0be0d4a3d",
#     "relpath": "validation/dogs/dog.1259.jpg"
#   },
#   {
#     "md5": "b64ced1e881cc37c0e0673bafe6e789c",
#     "relpath": "validation/dogs/dog.1260.jpg"
#   },
#   {
#     "md5": "694b68a388ff5cc611f4e9e779c84a72",
#     "relpath": "validation/dogs/dog.1261.jpg"
#   },
#   {
#     "md5": "cb393cdccfb8c4f32b4ebfa77fbb9f44",
#     "relpath": "validation/dogs/dog.1262.jpg"
#   },
#   {
#     "md5": "7e3e0244669f829d3d7d1720e3dee94c",
#     "relpath": "validation/dogs/dog.1263.jpg"
#   },
#   {
#     "md5": "29aa228c7eed12ae3750db8c1f8530cd",
#     "relpath": "validation/dogs/dog.1264.jpg"
#   },
#   {
#     "md5": "862c3bea14b1bc610a604fc7e3216946",
#     "relpath": "validation/dogs/dog.1265.jpg"
#   },
#   {
#     "md5": "5bc4643df7fc2728aabb5df6354300d8",
#     "relpath": "validation/dogs/dog.1266.jpg"
#   },
#   {
#     "md5": "8357caebaf4a3d84dc8c43956ecdfbb4",
#     "relpath": "validation/dogs/dog.1267.jpg"
#   },
#   {
#     "md5": "cd0daaa11dd046d79d2a44e60199bdad",
#     "relpath": "validation/dogs/dog.1268.jpg"
#   },
#   {
#     "md5": "df7cb2a9b656ae05f72f7c0bd146d6f9",
#     "relpath": "validation/dogs/dog.1269.jpg"
#   },
#   {
#     "md5": "03b4edde4b19e43c3f3e362b1f0cb9dc",
#     "relpath": "validation/dogs/dog.1270.jpg"
#   },
#   {
#     "md5": "880bc62590f65b8f47578abd866ebaaf",
#     "relpath": "validation/dogs/dog.1271.jpg"
#   },
#   {
#     "md5": "63153bc9cdcb8e28f095aeb978a56be7",
#     "relpath": "validation/dogs/dog.1272.jpg"
#   },
#   {
#     "md5": "90f26063b3bd40d0408692618fabee56",
#     "relpath": "validation/dogs/dog.1273.jpg"
#   },
#   {
#     "md5": "7897519aff9e1c793e9f059323e16196",
#     "relpath": "validation/dogs/dog.1274.jpg"
#   },
#   {
#     "md5": "39e95e49e9f318eaa7ee190fe7629d38",
#     "relpath": "validation/dogs/dog.1275.jpg"
#   },
#   {
#     "md5": "7263d2a6bc79d881023ea0b06050a6fa",
#     "relpath": "validation/dogs/dog.1276.jpg"
#   },
#   {
#     "md5": "f6aa6fa794d53842baf8b3c49b757438",
#     "relpath": "validation/dogs/dog.1277.jpg"
#   },
#   {
#     "md5": "fe61866b98d3ef16ab13c2762585f379",
#     "relpath": "validation/dogs/dog.1278.jpg"
#   },
#   {
#     "md5": "a8cad539851ae3e788d19f1894da6a9c",
#     "relpath": "validation/dogs/dog.1279.jpg"
#   },
#   {
#     "md5": "3225004c256c5cab8f10bcb340ca2b0e",
#     "relpath": "validation/dogs/dog.1280.jpg"
#   },
#   {
#     "md5": "2fb55edff69cb41baa43e9ef4713f30a",
#     "relpath": "validation/dogs/dog.1281.jpg"
#   },
#   {
#     "md5": "e2c6c5be47ebbd79febddcf54e91fc58",
#     "relpath": "validation/dogs/dog.1282.jpg"
#   },
#   {
#     "md5": "5780a14960bf5cfd159b4f6deb99cf18",
#     "relpath": "validation/dogs/dog.1283.jpg"
#   },
#   {
#     "md5": "0376f557aa7590fc76a743bb2ad8094a",
#     "relpath": "validation/dogs/dog.1284.jpg"
#   },
#   {
#     "md5": "db51dd549f9a92fd5dd06445c4202db7",
#     "relpath": "validation/dogs/dog.1285.jpg"
#   },
#   {
#     "md5": "c54005d25feed1264ee90f5b12354acc",
#     "relpath": "validation/dogs/dog.1286.jpg"
#   },
#   {
#     "md5": "58d3fb63550a3cb9095cde5f0786e151",
#     "relpath": "validation/dogs/dog.1287.jpg"
#   },
#   {
#     "md5": "834d2c82d18aef21bbbe51f982873f66",
#     "relpath": "validation/dogs/dog.1288.jpg"
#   },
#   {
#     "md5": "86d63230d61746084cf8f72909b6f37e",
#     "relpath": "validation/dogs/dog.1289.jpg"
#   },
#   {
#     "md5": "024cd1b7eeb056fbc102601a9f4a304d",
#     "relpath": "validation/dogs/dog.1290.jpg"
#   },
#   {
#     "md5": "d9e956f44e5cbdeb63e620ac872d4cfb",
#     "relpath": "validation/dogs/dog.1291.jpg"
#   },
#   {
#     "md5": "6c33588a4d96835909e7a4acd9699b71",
#     "relpath": "validation/dogs/dog.1292.jpg"
#   },
#   {
#     "md5": "072d5e35c315d9c2fe346213e98cf0d9",
#     "relpath": "validation/dogs/dog.1293.jpg"
#   },
#   {
#     "md5": "120deea00ed047420779989ee95385b3",
#     "relpath": "validation/dogs/dog.1294.jpg"
#   },
#   {
#     "md5": "4fbbff4091f11c8be7eb5587706d40dc",
#     "relpath": "validation/dogs/dog.1295.jpg"
#   },
#   {
#     "md5": "4f4ebed3abe40f08690dd60f7026dd9a",
#     "relpath": "validation/dogs/dog.1296.jpg"
#   },
#   {
#     "md5": "e12b3359e1c5c2b40e7a5695716bd276",
#     "relpath": "validation/dogs/dog.1297.jpg"
#   },
#   {
#     "md5": "52947433f489acdecc04d8caef978eba",
#     "relpath": "validation/dogs/dog.1298.jpg"
#   },
#   {
#     "md5": "eb6715d87d9bb54e59644ffa84904835",
#     "relpath": "validation/dogs/dog.1299.jpg"
#   },
#   {
#     "md5": "19b623eb268f7011e2a2ca6f182dd03d",
#     "relpath": "validation/dogs/dog.1300.jpg"
#   },
#   {
#     "md5": "8d0a0c1d4d014e96a460a200b963543c",
#     "relpath": "validation/dogs/dog.1301.jpg"
#   },
#   {
#     "md5": "f32fcabd6e6d8a7df7909e5ede02479b",
#     "relpath": "validation/dogs/dog.1302.jpg"
#   },
#   {
#     "md5": "e1c1f646f8b371ae911fcf38e3fcf01c",
#     "relpath": "validation/dogs/dog.1303.jpg"
#   },
#   {
#     "md5": "6a19a1e932952f3e1f6efade1f9c6ab4",
#     "relpath": "validation/dogs/dog.1304.jpg"
#   },
#   {
#     "md5": "7007af88ab239c4f3700893953309c19",
#     "relpath": "validation/dogs/dog.1305.jpg"
#   },
#   {
#     "md5": "54c0a30d73ec16194c682c41126bded6",
#     "relpath": "validation/dogs/dog.1306.jpg"
#   },
#   {
#     "md5": "a6f48d1be9bc655174cd0cabeac95ad8",
#     "relpath": "validation/dogs/dog.1307.jpg"
#   },
#   {
#     "md5": "5887a45d21960f7e0086f62283133476",
#     "relpath": "validation/dogs/dog.1308.jpg"
#   },
#   {
#     "md5": "fbf3002566d1427788bb30d63205b97b",
#     "relpath": "validation/dogs/dog.1309.jpg"
#   },
#   {
#     "md5": "5360beefc363514f0a0da12a78250159",
#     "relpath": "validation/dogs/dog.1310.jpg"
#   },
#   {
#     "md5": "827d84f9d7b10c2f30a5ec9f34e613d0",
#     "relpath": "validation/dogs/dog.1311.jpg"
#   },
#   {
#     "md5": "4bb1a3f736a288d2de66bb85e213bbb2",
#     "relpath": "validation/dogs/dog.1312.jpg"
#   },
#   {
#     "md5": "856768a244f9948b34106ff33753b53e",
#     "relpath": "validation/dogs/dog.1313.jpg"
#   },
#   {
#     "md5": "a73d99e274871b27940507afcbaf2b75",
#     "relpath": "validation/dogs/dog.1314.jpg"
#   },
#   {
#     "md5": "bf406e170b848239718bd3691c9bfeec",
#     "relpath": "validation/dogs/dog.1315.jpg"
#   },
#   {
#     "md5": "bcf55c43221071cbc60c91f1c804a3f4",
#     "relpath": "validation/dogs/dog.1316.jpg"
#   },
#   {
#     "md5": "0e10f9ecffdd3b4d80b085c471c74908",
#     "relpath": "validation/dogs/dog.1317.jpg"
#   },
#   {
#     "md5": "528553429832e43f731b8c6c1bec2921",
#     "relpath": "validation/dogs/dog.1318.jpg"
#   },
#   {
#     "md5": "6c3c252f13395e71143713fd9b4411c3",
#     "relpath": "validation/dogs/dog.1319.jpg"
#   },
#   {
#     "md5": "d79eeee5e02751a90ffaa9b477b41eec",
#     "relpath": "validation/dogs/dog.1320.jpg"
#   },
#   {
#     "md5": "16f0ffd088acc064994d5c0c54a120f7",
#     "relpath": "validation/dogs/dog.1321.jpg"
#   },
#   {
#     "md5": "e1e2288b172dcbb2d63bfeb3f3878636",
#     "relpath": "validation/dogs/dog.1322.jpg"
#   },
#   {
#     "md5": "95b1da6a9af401ca98f0dd1f0744bcd9",
#     "relpath": "validation/dogs/dog.1323.jpg"
#   },
#   {
#     "md5": "bd96239aac8e24c0ff11b9f4b080e902",
#     "relpath": "validation/dogs/dog.1324.jpg"
#   },
#   {
#     "md5": "7c62ee28d48599814e6082e295d6dd64",
#     "relpath": "validation/dogs/dog.1325.jpg"
#   },
#   {
#     "md5": "ad298a071bb38feab45739f3bb6c0e95",
#     "relpath": "validation/dogs/dog.1326.jpg"
#   },
#   {
#     "md5": "51151faef2895d22de2082e0ff188f7f",
#     "relpath": "validation/dogs/dog.1327.jpg"
#   },
#   {
#     "md5": "2d5a2a22133382945b89507770241cbf",
#     "relpath": "validation/dogs/dog.1328.jpg"
#   },
#   {
#     "md5": "f38304467ba740922c6059e42373a83b",
#     "relpath": "validation/dogs/dog.1329.jpg"
#   },
#   {
#     "md5": "f318139a1efd033d7b2ff5b5b8c29935",
#     "relpath": "validation/dogs/dog.1330.jpg"
#   },
#   {
#     "md5": "3d1aa3f29edcda74997da7c71cb533ca",
#     "relpath": "validation/dogs/dog.1331.jpg"
#   },
#   {
#     "md5": "9096958f45b22c6de75b12f3c903a046",
#     "relpath": "validation/dogs/dog.1332.jpg"
#   },
#   {
#     "md5": "e9de40504851a244656fac551cf5cf83",
#     "relpath": "validation/dogs/dog.1333.jpg"
#   },
#   {
#     "md5": "162bef0ec95238bf7bbe2d2c4fdba099",
#     "relpath": "validation/dogs/dog.1334.jpg"
#   },
#   {
#     "md5": "9d3eb42ee71df9aa9d33983258bb89b4",
#     "relpath": "validation/dogs/dog.1335.jpg"
#   },
#   {
#     "md5": "3609d8a3916476f5e8af952835151108",
#     "relpath": "validation/dogs/dog.1336.jpg"
#   },
#   {
#     "md5": "327f69814ee3ec514b9bc23136c479de",
#     "relpath": "validation/dogs/dog.1337.jpg"
#   },
#   {
#     "md5": "424824731967f0ff8df935be6c278050",
#     "relpath": "validation/dogs/dog.1338.jpg"
#   },
#   {
#     "md5": "5b83cfc3077ed5c331d85a9c13400257",
#     "relpath": "validation/dogs/dog.1339.jpg"
#   },
#   {
#     "md5": "3036dc6bdfdad4f68475a2d704a15b5a",
#     "relpath": "validation/dogs/dog.1340.jpg"
#   },
#   {
#     "md5": "bf57e6127614385c4ea7638ba855b560",
#     "relpath": "validation/dogs/dog.1341.jpg"
#   },
#   {
#     "md5": "63000f5f79ea6b4960eeb4ceaa0f4645",
#     "relpath": "validation/dogs/dog.1342.jpg"
#   },
#   {
#     "md5": "f2967efa2761539489f93ca1f2f0e4a9",
#     "relpath": "validation/dogs/dog.1343.jpg"
#   },
#   {
#     "md5": "c2de7e91a3c3dddd5c5a4cd03c81ad9f",
#     "relpath": "validation/dogs/dog.1344.jpg"
#   },
#   {
#     "md5": "76ec440632285ae813620ade1318fca7",
#     "relpath": "validation/dogs/dog.1345.jpg"
#   },
#   {
#     "md5": "a18340db1b4b7c5015de4e5367831625",
#     "relpath": "validation/dogs/dog.1346.jpg"
#   },
#   {
#     "md5": "ad6ccd82ca4503a7e22986f652132593",
#     "relpath": "validation/dogs/dog.1347.jpg"
#   },
#   {
#     "md5": "9fc6395419520f14d4cb0fbada9d3e5d",
#     "relpath": "validation/dogs/dog.1348.jpg"
#   },
#   {
#     "md5": "7c51af717d9388857e0a98095e725165",
#     "relpath": "validation/dogs/dog.1349.jpg"
#   },
#   {
#     "md5": "44a0e51ba1fb08351f042d7c07894a3a",
#     "relpath": "validation/dogs/dog.1350.jpg"
#   },
#   {
#     "md5": "42fdc14229da113664e012fa05481894",
#     "relpath": "validation/dogs/dog.1351.jpg"
#   },
#   {
#     "md5": "e8928fbe59bfa6d1317280d12e819e18",
#     "relpath": "validation/dogs/dog.1352.jpg"
#   },
#   {
#     "md5": "245b42ab217eb94e45f7b14d8154ce36",
#     "relpath": "validation/dogs/dog.1353.jpg"
#   },
#   {
#     "md5": "5f637df4cbf2e5ef32cd051738247636",
#     "relpath": "validation/dogs/dog.1354.jpg"
#   },
#   {
#     "md5": "ce73eec024a84fb753159f4c18c2dd41",
#     "relpath": "validation/dogs/dog.1355.jpg"
#   },
#   {
#     "md5": "d22d7fbbd260ad161fb9ba2ddfe9929d",
#     "relpath": "validation/dogs/dog.1356.jpg"
#   },
#   {
#     "md5": "0f3b71cd5e7e2adfdf2fc2aba849e3b6",
#     "relpath": "validation/dogs/dog.1357.jpg"
#   },
#   {
#     "md5": "db61d523b0cabc49dfd523a6694a113c",
#     "relpath": "validation/dogs/dog.1358.jpg"
#   },
#   {
#     "md5": "49107a94b66b8b1f3a60ba7228ada7d0",
#     "relpath": "validation/dogs/dog.1359.jpg"
#   },
#   {
#     "md5": "11885646829050d1e55baa617d84107c",
#     "relpath": "validation/dogs/dog.1360.jpg"
#   },
#   {
#     "md5": "97507f341d969124b0ca91a4d84d2e34",
#     "relpath": "validation/dogs/dog.1361.jpg"
#   },
#   {
#     "md5": "ba342e5e962969732280a0447d44d9d3",
#     "relpath": "validation/dogs/dog.1362.jpg"
#   },
#   {
#     "md5": "f50d90f5605164680c35846d2e8840b6",
#     "relpath": "validation/dogs/dog.1363.jpg"
#   },
#   {
#     "md5": "90c9a27bfc1ded02759a5ce0547b4f17",
#     "relpath": "validation/dogs/dog.1364.jpg"
#   },
#   {
#     "md5": "17d326437059fd7d099d8a55cfa78211",
#     "relpath": "validation/dogs/dog.1365.jpg"
#   },
#   {
#     "md5": "5b4d53b54b1c34473627dcfa05f74d87",
#     "relpath": "validation/dogs/dog.1366.jpg"
#   },
#   {
#     "md5": "62b64c42c6d9f812bb3e3c95674590d4",
#     "relpath": "validation/dogs/dog.1367.jpg"
#   },
#   {
#     "md5": "2859841c126e780956159cea7155c356",
#     "relpath": "validation/dogs/dog.1368.jpg"
#   },
#   {
#     "md5": "f3e42ba80771f4774efe424901e201ed",
#     "relpath": "validation/dogs/dog.1369.jpg"
#   },
#   {
#     "md5": "35f4827390bdf1bfd13d1cf47cbc0830",
#     "relpath": "validation/dogs/dog.1370.jpg"
#   },
#   {
#     "md5": "184ece54a54c5aa5fdd482b389602b3e",
#     "relpath": "validation/dogs/dog.1371.jpg"
#   },
#   {
#     "md5": "908f58a81f9000cc20c9562cf964bcf6",
#     "relpath": "validation/dogs/dog.1372.jpg"
#   },
#   {
#     "md5": "8f8b6bfe4d0d0a23daacd92b76942127",
#     "relpath": "validation/dogs/dog.1373.jpg"
#   },
#   {
#     "md5": "143c578e12bce8f66e3384abfe768b39",
#     "relpath": "validation/dogs/dog.1374.jpg"
#   },
#   {
#     "md5": "9c6d049a3f8737cd5d013a3b0f9d7122",
#     "relpath": "validation/dogs/dog.1375.jpg"
#   },
#   {
#     "md5": "0aae2ab0bec0fdfd43982e03e2e2f30d",
#     "relpath": "validation/dogs/dog.1376.jpg"
#   },
#   {
#     "md5": "d91109157f2ce78bdba9c9d195be1a4b",
#     "relpath": "validation/dogs/dog.1377.jpg"
#   },
#   {
#     "md5": "8c7c9fbd2aa762a9e6ebacc2444e6e73",
#     "relpath": "validation/dogs/dog.1378.jpg"
#   },
#   {
#     "md5": "2922127fc2d2d1abd7fee26da1aa75d4",
#     "relpath": "validation/dogs/dog.1379.jpg"
#   },
#   {
#     "md5": "15ef2036c32a3eba37214d5447e7fbbd",
#     "relpath": "validation/dogs/dog.1380.jpg"
#   },
#   {
#     "md5": "e9983db44b17e5a0644095bf1e15dc51",
#     "relpath": "validation/dogs/dog.1381.jpg"
#   },
#   {
#     "md5": "5b6fd2b4cecefc08ac85a85883e72014",
#     "relpath": "validation/dogs/dog.1382.jpg"
#   },
#   {
#     "md5": "1299e3ab5f2ca5c2ac7e825b6195c007",
#     "relpath": "validation/dogs/dog.1383.jpg"
#   },
#   {
#     "md5": "7265aad12d85414bcef86f15e1db3484",
#     "relpath": "validation/dogs/dog.1384.jpg"
#   },
#   {
#     "md5": "4387b95496c32e5154fff7006da309f9",
#     "relpath": "validation/dogs/dog.1385.jpg"
#   },
#   {
#     "md5": "322814cb91a654cafa59e243b775da22",
#     "relpath": "validation/dogs/dog.1386.jpg"
#   },
#   {
#     "md5": "6d3dd84a0d3db4883eff48b74c2022ad",
#     "relpath": "validation/dogs/dog.1387.jpg"
#   },
#   {
#     "md5": "b46b93d51be81b432ce8fd41fc27ec31",
#     "relpath": "validation/dogs/dog.1388.jpg"
#   },
#   {
#     "md5": "a3b2e7844547cda14aba1808114bf69d",
#     "relpath": "validation/dogs/dog.1389.jpg"
#   },
#   {
#     "md5": "74182cd0f94df0177600b822276a344a",
#     "relpath": "validation/dogs/dog.1390.jpg"
#   },
#   {
#     "md5": "ee92e899411f05824d02f72588814557",
#     "relpath": "validation/dogs/dog.1391.jpg"
#   },
#   {
#     "md5": "da210beeab4934602361fc593d0f2adb",
#     "relpath": "validation/dogs/dog.1392.jpg"
#   },
#   {
#     "md5": "a81ca37117a097a48c3253d788b66f1f",
#     "relpath": "validation/dogs/dog.1393.jpg"
#   },
#   {
#     "md5": "16d15b72c6547d8b1ac8661ac09ab02b",
#     "relpath": "validation/dogs/dog.1394.jpg"
#   },
#   {
#     "md5": "b8389ef9b69f493f47643f3b8ac2723c",
#     "relpath": "validation/dogs/dog.1395.jpg"
#   },
#   {
#     "md5": "7555004af8b729e708ab2386b6b4a284",
#     "relpath": "validation/dogs/dog.1396.jpg"
#   },
#   {
#     "md5": "b5fc3eaa5d8e1b1f3c9374742205eb5a",
#     "relpath": "validation/dogs/dog.1397.jpg"
#   },
#   {
#     "md5": "2d02b5c34b16cac723aec44172e4de37",
#     "relpath": "validation/dogs/dog.1398.jpg"
#   },
#   {
#     "md5": "e64a065ba0fc5a3a88b7050afd7b44af",
#     "relpath": "validation/dogs/dog.1399.jpg"
#   },
#   {
#     "md5": "adb29c1de1624c53c808f1a15bd332ba",
#     "relpath": "validation/dogs/dog.1400.jpg"
#   }
# ]

# %% [markdown]
# ```shell
# # Vamos rodar o MD5 em alguns arquivos para ver se os valores batem
# $ md5sum data/train/cats/cat.1.jpg data/train/cats/cat.10.jpg data/train/cats/cat.100.jpg
# ed779276108738fdb2179ccabf9680d9  data/train/cats/cat.1.jpg
# 10d2a131081a3095726c5721ed31c21f  data/train/cats/cat.10.jpg
# 0f2bfe74e9c363064087d0cd8a322106  data/train/cats/cat.100.jpg
# ```

# %% [markdown]
# ### Configuração do MinIO
#
# ```shell
# # Vamos configurar o MinIO como remote storage do DVC
# # Primeiro precisamos iniciar o MinIO
# $ cd minio
# $ docker compose up -d
#
# # Agora vamos criar um bucket para guardar os dados do DVC
# $ docker exec -it minio-local bash
#
# # Configuração das credenciais
# $ mc alias set local http://localhost:9000 minio "minio123,./"
# Added `local` successfully.
#
# # Criação do bucket
# $ mc mb local/dvc
# Bucket created successfully `local/dvc`.
#
# # List para conferir
# $ mc ls local/
# [2024-10-06 11:47:13 UTC]     0B dvc/
#
# # Vamos criar um par de access key e secret key para usar no DVC
# $ mc admin user svcacct add local minio \
# --name dvc \
# --access-key dvc \
# --secret-key dvcsecret
# Access Key: dvc
# Secret Key: dvcsecret
# Expiration: no-expiry
#
# # exit para sair do container do minio
# $ exit
# ```

# %% [markdown]
# ### Configuração do DVC Remote Storage
#
# ```shell
# # Adiciona o remote
# $ dvc remote add --default minio s3://dvc
# Setting 'minio' as a default remote.
#
# # Configura o endpoint
# $ dvc remote modify minio endpointurl http://localhost:9000
#
# # Configura o access key e o secret key
# $ dvc remote modify --local minio access_key_id dvc
# $ dvc remote modify --local minio secret_access_key dvcsecret
#
# # Conferindo as configurações
# $ cat .dvc/config
# [core]
#     remote = minio
# ['remote "minio"']
#     url = s3://dvc
#     endpointurl = http://localhost:9000
#
# # E as configurações de acesso?
# $ cat .dvc/config.local
# ['remote "minio"']
#     access_key_id = dvc
#     secret_access_key = dvcsecret
# ```

# %% [markdown]
# ### Usando o DVC Remote Storage
#
# ```shell
# # push para enviar os dados para o remote storage (MinIO)
# $ dvc push
# Pushing
# 1801 files pushed
#
# # vamos simular um ambiente novo, apagando a diretório de cache do DVC
# $ rm -rf .dvc/cache .dvc/tmp
#
# # pull para obter os dados no MinIO
# $ dvc pull
# Collecting                                                                                           |1.81k [00:00, 4.65kentry/s]
# Fetching
# Building workspace index                                                                             |1.81k [00:00, 5.41kentry/s]
# Comparing indexes                                                                                    |1.81k [00:00, 38.6kentry/s]
# Applying changes                                                                                       |0.00 [00:00,     ?file/s]
# 1801 files fetched
# ```

# %% [markdown]
# ###

# %% [markdown]
# ### Primeiro treinamento
#
# ```shell
# $ python train.py
# Found 1000 images belonging to 2 classes.
# 100/100 [==============================] - 22s 223ms/step
# Found 800 images belonging to 2 classes.
# 80/80 [==============================] - 18s 231ms/step
# 100%|██████████████████████████| 10/10 [00:04<00:00,  2.42epoch/s, loss=0.118, accuracy=0.96, val_loss=0.494, val_accuracy=0.889]
# ```
#
# ### Adição do modelo no dvc
#
# ```shell
# $ dvc add model.weights.h5
# 100% Adding...|█████████████████████████████████████████████████████████████████████████████████████████|1/1 [00:00, 31.85file/s]
#
# To track the changes with git, run:
#         git add .gitignore model.weights.h5.dvc
#
# To enable auto staging, run:
#         dvc config core.autostage true
# ```
#
# ### Versionamento do arquivo dvc
#
# ```shell
# $ git add model.weights.h5.dvc metrics.csv .gitignore
# $ git commit -s -m "Primeiro modelo, treinado com 1000 imagens"
# [main 5fbd6f1] Primeiro modelo, treinado com 1000 imagens
#  3 files changed, 17 insertions(+)
#  create mode 100644 metrics.csv
#  create mode 100644 model.weights.h5.dvc
#
# $ git tag -a "v1.0" -m "Modelo v1.0, 1000 imagens"
# ```

# %% [markdown]
# ### Novos dados
#
# ```shell
# $ dvc get https://github.com/iterative/dataset-registry tutorials/versioning/new-labels.zip
# $ unzip -q new-labels.zip
# $ rm -f new-labels.zip
# ```
#
# ### Versionamento dos novos dados
#
# ```shell
# $ dvc add data
# 100% Adding...|█████████████████████████████████████████████████████████████████████████████████████████|1/1 [00:00,  2.23file/s]
# To track the changes with git, run:
#         git add data.dvc
#
# To enable auto staging, run:
#         dvc config core.autostage true
#
# $ dvc push
# Pushing
# 1002 files pushed
#
# $ git add data.dvc
# $ git commit -s -m "Novos dados"
# [main e040efd] Novos dados
#  1 file changed, 3 insertions(+), 3 deletions(-)
#
# $ git tag -a "v1.1" -m "Novos dados"
# ```

# %% [markdown]
# ### Segundo treinamento
#
# ```shell
# $ python train.py
# Found 2000 images belonging to 2 classes.
# 200/200 [==============================] - 44s 219ms/step
# Found 800 images belonging to 2 classes.
# 80/80 [==============================] - 19s 232ms/step
# 100%|██████████████████████████| 10/10 [00:07<00:00,  1.30epoch/s, loss=0.155, accuracy=0.947, val_loss=0.606, val_accuracy=0.87]
# ```
#
# ### Adição do segundo modelo no DVC
#
# ```shell
# $ dvc add model.weights.h5
# 100% Adding...|█████████████████████████████████████████████████████████████████████████████████████████|1/1 [00:00, 31.35file/s]
# To track the changes with git, run:
#         git add model.weights.h5.dvc
#
# To enable auto staging, run:
#         dvc config core.autostage true
#
# $ dvc push
# Collecting                                                                       |2.81k [00:00, 20.5kentry/s]
# Pushing
# 1 file pushed
# ```
#
# ### Versionamento do segundo modelo
#
# ```shell
# $ git add model.weights.h5.dvc metrics.csv
#
# $ git commit -s -m "Segundo modelo, treinado com 2000 imagens"
# main 40d35ed] Segundo modelo, treinado com 2000 imagens
#  2 files changed, 11 insertions(+), 11 deletions(-)
#
# $ git tag -a "v2.0" -m "Modelo v2.0, 2000 imagens"
# ```

# %% [markdown]
# ### Mudando versões dos dados
#
# ```shell
# # Podemos voltar para a versão v1.0 voltando todo o código através da tag
# $ git checkout v1.0
# $ dvc checkout
#
# # Também podemos voltar apenas o dado e manter o código na última versão
# $ cat data.dvc
# outs:
# - md5: 21060888834f7220846d1c6f6c04e649.dir
#   size: 64128504
#   nfiles: 2800
#   hash: md5
#   path: data
#
# $ git checkout v1.0 data.dvc
# $ cat data.dvc
# outs:
# - md5: b8f4d5a78e55e88906d5f4aeaf43802e.dir
#   size: 41149064
#   nfiles: 1800
#   hash: md5
#   path: data
#
# # Será que os dados estão corretos?
# $ find data/ -not -type d | wc -l
#   2800
#
# $ dvc checkout
# Building workspace index                                                         |2.81k [00:00, 46.6kentry/s]
# Comparing indexes                                                                |2.81k [00:00, 86.4kentry/s]
# Applying changes                                                                   |0.00 [00:00,     ?file/s]
# M       data/
#
# # Agora sim
# $ find data/ -not -type d | wc -l
#   1800
# ```

# %% [markdown]
# ### Criando estágios no DVC
#
# ```shell
# # Primeiro é necessário remover o modelo do DVC (vamos adicionar novamente logo abaixo)
# $ dvc remove model.weights.h5.dvc
#
# # Criação do stage
# $ dvc stage add --name train --deps train.py --deps data \
# --outs model.weights.h5 --outs bottleneck_features_train.npy --outs bottleneck_features_validation.npy \
# --metrics-no-cache metrics.csv \
# python train.py
# Added stage 'train' in 'dvc.yaml'
#
# To track the changes with git, run:
#         git add .gitignore dvc.yaml
#
# To enable auto staging, run:
#         dvc config core.autostage true
# ```
#
# ### Execução do estágio
#
# ```shell
# $ dvc repro
# 'data.dvc' didn't change, skipping
# Running stage 'train':
# > python train.py
# Found 2000 images belonging to 2 classes.
# 200/200 [==============================] - 47s 235ms/step
# Found 800 images belonging to 2 classes.
# 80/80 [==============================] - 19s 239ms/step
# 100%|█████████████████████████| 10/10 [00:07<00:00,  1.26epoch/s, loss=0.148, accuracy=0.949, val_loss=0.424, val_accuracy=0.889]
# Generating lock file 'dvc.lock'
# Updating lock file 'dvc.lock'
#
# To track the changes with git, run:
#
#         git add dvc.lock
#
# To enable auto staging, run:
#
#         dvc config core.autostage true
# Use `dvc push` to send your updates to remote storage.
# ```
